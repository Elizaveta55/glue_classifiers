# %%
# !pip install lazypredict
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lazypredict in c:\users\kolma\appdata\roaming\python\python37\site-packages (0.2.9)
# Requirement already satisfied: numpy==1.19.1 in c:\users\kolma\appdata\roaming\python\python37\site-packages (from lazypredict) (1.19.1)
# Requirement already satisfied: joblib==1.0.0 in c:\users\kolma\appdata\roaming\python\python37\site-packages (from lazypredict) (1.0.0)
# Requirement already satisfied: tqdm==4.56.0 in c:\users\kolma\appdata\roaming\python\python37\site-packages (from lazypredict) (4.56.0)
# Requirement already satisfied: lightgbm==2.3.1 in c:\users\kolma\appdata\roaming\python\python37\site-packages (from lazypredict) (2.3.1)
# Requirement already satisfied: xgboost==1.1.1 in c:\users\kolma\appdata\roaming\python\python37\site-packages (from lazypredict) (1.1.1)
# Requirement already satisfied: pytest==5.4.3 in c:\users\kolma\appdata\roaming\python\python37\site-packages (from lazypredict) (5.4.3)
# Requirement already satisfied: click==7.1.2 in c:\program files\python37\lib\site-packages (from lazypredict) (7.1.2)
# Requirement already satisfied: six==1.15.0 in c:\program files\python37\lib\site-packages (from lazypredict) (1.15.0)
# Requirement already satisfied: PyYAML==5.3.1 in c:\users\kolma\appdata\roaming\python\python37\site-packages (from lazypredict) (5.3.1)
# Requirement already satisfied: pandas==1.0.5 in c:\users\kolma\appdata\roaming\python\python37\site-packages (from lazypredict) (1.0.5)
# Requirement already satisfied: scikit-learn==0.23.1 in c:\users\kolma\appdata\roaming\python\python37\site-packages (from lazypredict) (0.23.1)
# Requirement already satisfied: scipy==1.5.4 in c:\users\kolma\appdata\roaming\python\python37\site-packages (from lazypredict) (1.5.4)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\kolma\appdata\roaming\python\python37\site-packages (from pandas==1.0.5->lazypredict) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\kolma\appdata\roaming\python\python37\site-packages (from pandas==1.0.5->lazypredict) (2020.1)
# Requirement already satisfied: pluggy<1.0,>=0.12 in c:\users\kolma\appdata\roaming\python\python37\site-packages (from pytest==5.4.3->lazypredict) (0.13.1)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\kolma\appdata\roaming\python\python37\site-packages (from pytest==5.4.3->lazypredict) (1.4.0)
# Requirement already satisfied: packaging in c:\program files\python37\lib\site-packages (from pytest==5.4.3->lazypredict) (21.3)
# Requirement already satisfied: more-itertools>=4.0.0 in c:\users\kolma\appdata\roaming\python\python37\site-packages (from pytest==5.4.3->lazypredict) (8.12.0)
# Requirement already satisfied: py>=1.5.0 in c:\users\kolma\appdata\roaming\python\python37\site-packages (from pytest==5.4.3->lazypredict) (1.11.0)
# Requirement already satisfied: importlib-metadata>=0.12 in c:\program files\python37\lib\site-packages (from pytest==5.4.3->lazypredict) (2.0.0)
# Requirement already satisfied: colorama in c:\program files\python37\lib\site-packages (from pytest==5.4.3->lazypredict) (0.4.4)
# Requirement already satisfied: attrs>=17.4.0 in c:\program files\python37\lib\site-packages (from pytest==5.4.3->lazypredict) (20.2.0)
# Requirement already satisfied: wcwidth in c:\program files\python37\lib\site-packages (from pytest==5.4.3->lazypredict) (0.2.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kolma\appdata\roaming\python\python37\site-packages (from scikit-learn==0.23.1->lazypredict) (2.1.0)
# Requirement already satisfied: zipp>=0.5 in c:\program files\python37\lib\site-packages (from importlib-metadata>=0.12->pytest==5.4.3->lazypredict) (3.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\program files\python37\lib\site-packages (from packaging->pytest==5.4.3->lazypredict) (2.4.7)
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\kolma\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\kolma\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\kolma\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\kolma\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\kolma\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -pencv-contrib-python (c:\users\kolma\appdata\roaming\python\python37\site-packages)
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\program files\python37\python.exe -m pip install --upgrade pip' command.

# %%
import os
import sys
import shutil
import tempfile
import urllib.request
import zipfile
from sklearn.metrics import log_loss, f1_score, roc_curve, auc


TASKS = ["CoLA", "SST", "RTE"]
TASK2PATH = {"CoLA":'https://dl.fbaipublicfiles.com/glue/data/CoLA.zip',
             "SST":'https://dl.fbaipublicfiles.com/glue/data/SST-2.zip',
             "RTE":'https://dl.fbaipublicfiles.com/glue/data/RTE.zip'}

def download_and_extract(task, data_dir):
    print("Downloading and extracting %s..." % task)
    data_file = "%s.zip" % task
    urllib.request.urlretrieve(TASK2PATH[task], data_file)
    with zipfile.ZipFile(data_file) as zip_ref:
        zip_ref.extractall(data_dir)
    os.remove(data_file)
    print("\tCompleted!")
    

def get_tasks(task_names):
    if "all" in task_names:
        tasks = TASKS
    else:
        tasks = []
        for task_name in task_names:
            assert task_name in TASKS, "Task %s not found!" % task_name
            tasks.append(task_name)
    return tasks

def main():
    tasks = get_tasks('all')

    for task in tasks:
      download_and_extract(task, 'data')

main()
# Out:
# Downloading and extracting CoLA...
# 	Completed!
# Downloading and extracting SST...
# 	Completed!
# Downloading and extracting RTE...
# 	Completed!

# %% [markdown]
# # **SST-2 Classifier**
#
# Here we apply only one representation function - word2vec and different configurations of simple LSTM model and basic classifiers

# %%
## SST-2
import pandas as pd

data_pth = 'data'
TASKS = ["CoLA", "SST-2", "RTE"]

train_data = pd.read_table(os.path.join(data_pth, TASKS[1], 'train.tsv'))
test_data = pd.read_table(os.path.join(data_pth, TASKS[1], 'dev.tsv'))

# %%
test_data
# Out:
#                                               sentence  label
# 0      it 's a charming and often affecting journey .       1
# 1                   unflinchingly bleak and desperate       0
# 2    allows us to hope that nolan is poised to emba...      1
# 3    the acting , costumes , music , cinematography...      1
# 4                    it 's slow -- very , very slow .       0
# ..                                                 ...    ...
# 867              has all the depth of a wading pool .       0
# 868              a movie with a real anarchic flair .       1
# 869  a subject like this should inspire reaction in...      0
# 870  ... is an arthritic attempt at directing by ca...      0
# 871  looking aristocratic , luminous yet careworn i...      1
#
# [872 rows x 2 columns]

# %%
x_train = train_data.loc[:,'sentence']
y_train = train_data.loc[:,'label']
x_test = test_data.loc[:,'sentence']
y_test = test_data.loc[:,'label']

# %%
x_train
# Out:
# 0             hide new secretions from the parental units
# 1                     contains no wit , only labored gags
# 2        that loves its characters and communicates som...
# 3        remains utterly satisfied to remain the same t...
# 4        on the worst revenge-of-the-nerds clichés the ...
#                                ...
# 67344                                 a delightful comedy
# 67345                     anguish , anger and frustration
# 67346    at achieving the modest , crowd-pleasing goals...
# 67347                                    a patient viewer
# 67348    this new jangle of noise , mayhem and stupidit...
# Name: sentence, Length: 67349, dtype: object

# %% [markdown]
# ## Doc2Vec

# %%
# !pip install --upgrade numpy

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))

def cosine(u, v):
    return np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))

def sent_tokenize(sents):
  tokenized_sent = []
  for s in sents:
    word_tokens = word_tokenize(s.lower())
    filtered_sentence = [w for w in word_tokens if w not in stop_words]
    tokenized_sent.append(filtered_sentence)
  return [TaggedDocument(d, [i]) for i, d in enumerate(tokenized_sent)]

tagged_train_sent = sent_tokenize(x_train)
tagged_test_sent = sent_tokenize(x_test)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kolma\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kolma\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
tagged_train_sent
# Out:
# [TaggedDocument(words=['hide', 'new', 'secretions', 'parental', 'units'], tags=[0]),
#  TaggedDocument(words=['contains', 'wit', ',', 'labored', 'gags'], tags=[1]),
#  TaggedDocument(words=['loves', 'characters', 'communicates', 'something', 'rather', 'beautiful', 'human', 'nature'], tags=[2]),
#  TaggedDocument(words=['remains', 'utterly', 'satisfied', 'remain', 'throughout'], tags=[3]),
#  TaggedDocument(words=['worst', 'revenge-of-the-nerds', 'clichés', 'filmmakers', 'could', 'dredge'], tags=[4]),
#  TaggedDocument(words=["'s", 'far', 'tragic', 'merit', 'superficial', 'treatment'], tags=[5]),
#  TaggedDocument(words=['demonstrates', 'director', 'hollywood', 'blockbusters', 'patriot', 'games', 'still', 'turn', 'small', ',', 'personal', 'film', 'emotional', 'wallop', '.'], tags=[6]),
#  TaggedDocument(words=['saucy'], tags=[7]),
#  TaggedDocument(words=['depressed', 'fifteen-year-old', "'s", 'suicidal', 'poetry'], tags=[8]),
#  TaggedDocument(words=['deeply', 'thought', '`', 'right-thinking', "'", 'films'], tags=[9]),
#  TaggedDocument(words=['goes', 'absurd', 'lengths'], tags=[10]),
#  TaggedDocument(words=['moviegoers', 'complain', '`', "n't", 'make', 'movies', 'like', 'used', 'anymore'], tags=[11]),
#  TaggedDocument(words=['part', 'nothing', "'s", 'happening', ','], tags=[12]),
#  TaggedDocument(words=['saw', 'bad', 'movie'], tags=[13]),
#  TaggedDocument(words=['lend', 'dignity', 'dumb', 'story'], tags=[14]),
#  TaggedDocument(words=['greatest', 'musicians'], tags=[15]),
#  TaggedDocument(words=['cold', 'movie'], tags=[16]),
#  TaggedDocument(words=['usual', 'intelligence', 'subtlety'], tags=[17]),
#  TaggedDocument(words=['redundant', 'concept'], tags=[18]),
#  TaggedDocument(words=['swimming', 'young', 'woman', "'s", 'face', ',', 'casting', 'actress', 'whose', 'face', 'projects', 'woman', "'s", 'doubts', 'yearnings', ',', 'succeeds', '.'], tags=[19]),
#  TaggedDocument(words=['equals', 'original', 'ways', 'even', 'betters'], tags=[20]),
#  TaggedDocument(words=['anything', ',', 'see', 'karen', 'black', ',', 'camps', 'storm', 'fringe', 'feminist', 'conspiracy', 'theorist', 'named', 'dirty', 'dick', '.'], tags=[21]),
#  TaggedDocument(words=['smile', 'face'], tags=[22]),
#  TaggedDocument(words=['comes', 'brave', ',', 'uninhibited', 'performances'], tags=[23]),
#  TaggedDocument(words=['excruciatingly', 'unfunny', 'pitifully', 'unromantic'], tags=[24]),
#  TaggedDocument(words=['enriched', 'imaginatively', 'mixed', 'cast', 'antic', 'spirits'], tags=[25]),
#  TaggedDocument(words=['half', 'dragonfly', 'worse', ':', 'part', 'nothing', "'s", 'happening', ',', 'part', 'something', "'s", 'happening'], tags=[26]),
#  TaggedDocument(words=['world', 'cinema'], tags=[27]),
#  TaggedDocument(words=['good', 'viewing', 'alternative'], tags=[28]),
#  TaggedDocument(words=['plot', 'nothing', 'boilerplate', 'clichés', 'start', 'finish', ','], tags=[29]),
#  TaggedDocument(words=['action', 'stilted'], tags=[30]),
#  TaggedDocument(words=['cylinders'], tags=[31]),
#  TaggedDocument(words=['find', 'little', 'interest', 'film', ',', 'often', 'preachy', 'poorly', 'acted'], tags=[32]),
#  TaggedDocument(words=['far', 'worst', 'movie', 'year'], tags=[33]),
#  TaggedDocument(words=['sit', ','], tags=[34]),
#  TaggedDocument(words=['another', '``', 'best', 'man', '``', 'clone', 'weaving', 'theme', 'throughout', 'funny', 'film'], tags=[35]),
#  TaggedDocument(words=["'s", 'issues', 'adults', 'face', 'marriage', 'think', "'s", 'liked', '--', 'real', 'issues', 'tucked', 'silly', 'crude', 'storyline'], tags=[36]),
#  TaggedDocument(words=['heroes'], tags=[37]),
#  TaggedDocument(words=['oblivious', 'existence', 'film'], tags=[38]),
#  TaggedDocument(words=['sharply'], tags=[39]),
#  TaggedDocument(words=['entire', 'point', 'shaggy', 'dog', 'story', ',', 'course', ',', 'goes', 'nowhere', ',', 'classic', 'nowheresville', 'every', 'sense', '.'], tags=[40]),
#  TaggedDocument(words=['sometimes', 'dry'], tags=[41]),
#  TaggedDocument(words=['come', ',', 'already', 'recycled', 'times', "'d", 'care', 'count'], tags=[42]),
#  TaggedDocument(words=['covers', 'territory', 'wit', 'originality', ',', 'suggesting', 'fourth', 'feature'], tags=[43]),
#  TaggedDocument(words=['$', '40', 'million', 'version', 'game'], tags=[44]),
#  TaggedDocument(words=['gorgeous', 'deceptively', 'minimalist'], tags=[45]),
#  TaggedDocument(words=['cross', 'swords', 'best'], tags=[46]),
#  TaggedDocument(words=['fringe', 'feminist', 'conspiracy', 'theorist'], tags=[47]),
#  TaggedDocument(words=['proves', "n't", 'lost', 'touch', ',', 'bringing', 'superb', 'performance', 'admittedly', 'middling', 'film', '.'], tags=[48]),
#  TaggedDocument(words=['disappointments'], tags=[49]),
#  TaggedDocument(words=['horrors'], tags=[50]),
#  TaggedDocument(words=['muddle', 'splashed', 'bloody', 'beauty', 'vivid', 'scorsese', 'ever', 'given', 'us', '.'], tags=[51]),
#  TaggedDocument(words=['many', 'pointless'], tags=[52]),
#  TaggedDocument(words=['beautifully'], tags=[53]),
#  TaggedDocument(words=['contrived', ',', 'well-worn', 'situations'], tags=[54]),
#  TaggedDocument(words=['doa'], tags=[55]),
#  TaggedDocument(words=['poor', 'ben', 'bratt', 'could', "n't", 'find', 'stardom', 'mapquest', 'emailed', 'point-to-point', 'driving', 'directions', '.'], tags=[56]),
#  TaggedDocument(words=['subtle', 'touching', 'son', "'s", 'room'], tags=[57]),
#  TaggedDocument(words=['starts', 'legend'], tags=[58]),
#  TaggedDocument(words=['far', 'less', 'sophisticated'], tags=[59]),
#  TaggedDocument(words=['rich', 'veins', 'funny', 'stuff', 'movie'], tags=[60]),
#  TaggedDocument(words=['apparent', 'joy'], tags=[61]),
#  TaggedDocument(words=['shot', 'ugly', 'digital', 'video'], tags=[62]),
#  TaggedDocument(words=['...', 'sour', 'little', 'movie', 'core', ';', 'exploration', 'emptiness', 'underlay', 'relentless', 'gaiety', '1920', "'s", '...', 'film', "'s", 'ending', '``', '?', '``'], tags=[63]),
#  TaggedDocument(words=['though', 'ford', 'neeson', 'capably', 'hold', 'interest', ',', 'thrilling', 'movie'], tags=[64]),
#  TaggedDocument(words=['pretty', 'damned', 'funny', '.'], tags=[65]),
#  TaggedDocument(words=['never', 'feel', 'anything', 'characters'], tags=[66]),
#  TaggedDocument(words=["'s", 'lousy', 'one'], tags=[67]),
#  TaggedDocument(words=['corporate', 'circus', 'recording', 'industry', 'current', 'climate', 'mergers', 'downsizing'], tags=[68]),
#  TaggedDocument(words=['storylines', 'woven', 'together', 'skilfully', ',', 'magnificent', 'swooping', 'aerial', 'shots', 'breathtaking', ',', 'overall', 'experience', 'awesome', '.'], tags=[69]),
#  TaggedDocument(words=['highly-praised', 'disappointments'], tags=[70]),
#  TaggedDocument(words=['sounds', 'like', 'cruel', 'deception', 'carried', 'men', 'marginal', 'intelligence', ',', 'reactionary', 'ideas', 'women', 'total', 'lack', 'empathy', '.'], tags=[71]),
#  TaggedDocument(words=['seem', 'fresh'], tags=[72]),
#  TaggedDocument(words=['dustbin', 'history'], tags=[73]),
#  TaggedDocument(words=['director', ',', 'eastwood', 'game'], tags=[74]),
#  TaggedDocument(words=['pays', 'earnest', 'homage', 'turntablists'], tags=[75]),
#  TaggedDocument(words=['weak'], tags=[76]),
#  TaggedDocument(words=['skip', 'dreck', ','], tags=[77]),
#  TaggedDocument(words=['contains', 'laughs', 'even', 'less', 'surprises'], tags=[78]),
#  TaggedDocument(words=['film', 'affirm', 'love', "'s", 'power', 'help', 'people', 'endure', 'almost', 'unimaginable', 'horror'], tags=[79]),
#  TaggedDocument(words=['absolute', 'joy'], tags=[80]),
#  TaggedDocument(words=['generates'], tags=[81]),
#  TaggedDocument(words=[',', 'like', 'life', ',', "n't", 'much', 'fun', 'without', 'highs', 'lows'], tags=[82]),
#  TaggedDocument(words=['based', 'true', 'historically', 'significant', 'story'], tags=[83]),
#  TaggedDocument(words=['well-rounded', 'tribute'], tags=[84]),
#  TaggedDocument(words=[',', 'though', 'many', 'actors', 'throw', 'spark', 'two', 'first', 'appear', ',', 'ca', "n't", 'generate', 'enough', 'heat', 'cold', 'vacuum', 'comedy', 'start', 'reaction', '.'], tags=[85]),
#  TaggedDocument(words=['much', 'like', 'young', 'robert', 'deniro'], tags=[86]),
#  TaggedDocument(words=['khouri', 'manages', ',', 'terrific', 'flair', ',', 'keep', 'extremes', 'screwball', 'farce', 'blood-curdling', 'family', 'intensity', 'one', 'continuum', '.'], tags=[87]),
#  TaggedDocument(words=['fashioning', 'engrossing', 'entertainment'], tags=[88]),
#  TaggedDocument(words=['spiffy', 'animated', 'feature'], tags=[89]),
#  TaggedDocument(words=["'s", 'sloppily', 'written', 'cast', 'believe', 'anyone', 'central', 'creation', 'bugsy', 'caterer'], tags=[90]),
#  TaggedDocument(words=['alternating', 'facetious', 'comic', 'parody', 'pulp', 'melodrama', ',', 'smart-aleck', 'movie', '...', 'tosses', 'around', 'intriguing', 'questions', 'difference', 'human', 'android', 'life'], tags=[91]),
#  TaggedDocument(words=['strung-together', 'moments'], tags=[92]),
#  TaggedDocument(words=[',', 'generous', 'subversive', 'artworks'], tags=[93]),
#  TaggedDocument(words=["n't", 'follow', 'stale', ',', 'standard', ',', 'connect-the-dots', 'storyline', 'become', 'commonplace', 'movies', 'explore', 'seamy', 'underbelly', 'criminal', 'world'], tags=[94]),
#  TaggedDocument(words=['funny', 'yet'], tags=[95]),
#  TaggedDocument(words=['overbearing', 'over-the-top'], tags=[96]),
#  TaggedDocument(words=["'s", 'robert', 'duvall', '!'], tags=[97]),
#  TaggedDocument(words=['rich', 'sudden', 'wisdom'], tags=[98]),
#  TaggedDocument(words=['acted', 'directed', ',', "'s", 'clear', 'washington', 'certainly', 'new', 'career', 'ahead'], tags=[99]),
#  TaggedDocument(words=['memory'], tags=[100]),
#  TaggedDocument(words=['respectable', 'new', 'one'], tags=[101]),
#  TaggedDocument(words=['yet', 'grating', 'showcase'], tags=[102]),
#  TaggedDocument(words=['hate', 'tear', 'eyes', 'away', 'images', 'long', 'enough', 'read', 'subtitles'], tags=[103]),
#  TaggedDocument(words=['addition', 'sporting', 'one', 'worst', 'titles', 'recent', 'cinematic', 'history'], tags=[104]),
#  TaggedDocument(words=[',', 'gender-bending', 'comedy', 'generally', 'quite', 'funny', '.'], tags=[105]),
#  TaggedDocument(words=['build', 'robots', ',', 'haul', "'em", 'theater', 'late', 'show', ',', 'put', 'mystery', 'science', 'theatre', '3000', 'tribute', 'almost', 'certainly', 'going', 'go', 'worst', '--', '--', 'killer', 'website', 'movie', 'year'], tags=[106]),
#  TaggedDocument(words=["n't", 'work', 'concert'], tags=[107]),
#  TaggedDocument(words=['direction', 'fluid', ',', 'no-nonsense', 'authority', ',', 'performances', 'harris', ',', 'phifer', 'cam', '`', 'ron', 'seal', 'deal', '.'], tags=[108]),
#  TaggedDocument(words=['would', 'liked', 'gone', 'one', 'step'], tags=[109]),
#  TaggedDocument(words=["'s", 'harsh', 'work', 'piece', 'storytelling', ','], tags=[110]),
#  TaggedDocument(words=['hawaiian', 'shirt'], tags=[111]),
#  TaggedDocument(words=['takes', 'classic', 'story', ',', 'casts', 'attractive', 'talented', 'actors', 'uses', 'magnificent', 'landscape', 'create', 'feature', 'film', 'wickedly', 'fun', 'watch', '.'], tags=[112]),
#  TaggedDocument(words=['provide', 'keenest', 'pleasures'], tags=[113]),
#  TaggedDocument(words=['altogether', 'slight', 'called', 'kind', 'masterpiece'], tags=[114]),
#  TaggedDocument(words=['grievous'], tags=[115]),
#  TaggedDocument(words=['laugh', '(', 'maybe', 'twice', ')', ',', 'completely', 'forgotten', 'movie', 'time', 'get', 'back', 'car', 'parking', 'lot', '.'], tags=[116]),
#  TaggedDocument(words=['hopeless'], tags=[117]),
#  TaggedDocument(words=['unpretentious', ',', 'charming', ',', 'quirky', ',', 'original'], tags=[118]),
#  TaggedDocument(words=['nicks', 'steinberg', 'match', 'creations', 'pure', 'venality', '--', "'s", 'giving', 'old', 'college', 'try', '.'], tags=[119]),
#  TaggedDocument(words=['well-written', 'well-acted', '.'], tags=[120]),
#  TaggedDocument(words=["n't", 'many', 'conclusive', 'answers', 'film'], tags=[121]),
#  TaggedDocument(words=['clumsy', 'dialogue', ',', 'heavy-handed', 'phoney-feeling', 'sentiment', ','], tags=[122]),
#  TaggedDocument(words=['proves', 'lovely', 'trifle', ',', 'unfortunately', ',', 'little', 'love', 'cuteness', '.'], tags=[123]),
#  TaggedDocument(words=['bring', 'tissues', '.'], tags=[124]),
#  TaggedDocument(words=['film', "'s", 'mid-to-low', 'budget', 'betrayed', 'surprisingly', 'shoddy', 'makeup', 'work', '.'], tags=[125]),
#  TaggedDocument(words=['brings', 'proper', 'conviction', 'role', '(', 'jason', 'bourne', ')', '.'], tags=[126]),
#  TaggedDocument(words=['young', 'woman', 'great', 'charm', ',', 'generosity', 'diplomacy'], tags=[127]),
#  TaggedDocument(words=["'s", 'something', 'poignant', 'artist', '90-plus', 'years', 'taking', 'effort', 'share', 'impressions', 'life', 'loss', 'time', 'art', 'us', '.'], tags=[128]),
#  TaggedDocument(words=['silly'], tags=[129]),
#  TaggedDocument(words=['cinematic', 'bon', 'bons'], tags=[130]),
#  TaggedDocument(words=['supremely', 'unfunny', 'unentertaining', 'watch', 'middle-age'], tags=[131]),
#  TaggedDocument(words=['lively', 'engaging', 'examination', 'similar', 'obsessions', 'dominate', 'family', '.'], tags=[132]),
#  TaggedDocument(words=['irritates'], tags=[133]),
#  TaggedDocument(words=['collapse'], tags=[134]),
#  TaggedDocument(words=['many', 'challenges', 'poses', 'one', 'forgive', 'film', 'flaws'], tags=[135]),
#  TaggedDocument(words=[',', 'serves', 'workable', 'primer', 'region', "'s", 'recent', 'history', ',', 'would', 'make', 'terrific', '10th-grade', 'learning', 'tool', '.'], tags=[136]),
#  TaggedDocument(words=['wide-awake', 'way'], tags=[137]),
#  TaggedDocument(words=['(', 'vainly', ',', 'think', ')'], tags=[138]),
#  TaggedDocument(words=['one', 'big', 'excuse', 'play', 'one', 'lewd', 'scene', 'another', '.'], tags=[139]),
#  TaggedDocument(words=['effective', 'stick'], tags=[140]),
#  TaggedDocument(words=['underscore', 'importance', 'family', 'tradition', 'familial', 'community'], tags=[141]),
#  TaggedDocument(words=['delivers', 'promises', ':', 'look', '``', 'wild', 'ride', '``', 'ensues', 'brash', 'young', 'men', 'set', 'conquer', 'online', 'world', 'laptops', ',', 'cell', 'phones', 'sketchy', 'business', 'plans'], tags=[142]),
#  TaggedDocument(words=['watching', 'digital-effects-heavy', ',', 'supposed', 'family-friendly', 'comedy'], tags=[143]),
#  TaggedDocument(words=['absolutely', 'completely', 'ridiculous'], tags=[144]),
#  TaggedDocument(words=["'s", 'tasteful', 'rock', 'roll', 'movie', '.'], tags=[145]),
#  TaggedDocument(words=['movie', 'almost', 'completely', 'lacking', 'suspense', ',', 'surprise', 'consistent', 'emotional', 'conviction', '.'], tags=[146]),
#  TaggedDocument(words=['realistic', 'portrayal'], tags=[147]),
#  TaggedDocument(words=['trying', 'grab', 'lump', 'play-doh', ',', 'harder', 'liman', 'tries', 'squeeze', 'story'], tags=[148]),
#  TaggedDocument(words=['well-thought', 'stunts'], tags=[149]),
#  TaggedDocument(words=['reveals', 'important', 'special', 'talents', 'put', 'service', 'others', '.'], tags=[150]),
#  TaggedDocument(words=['lika', 'da'], tags=[151]),
#  TaggedDocument(words=['welcome', 'relief'], tags=[152]),
#  TaggedDocument(words=['promise', 'digital', 'filmmaking'], tags=[153]),
#  TaggedDocument(words=['one', 'could', 'easily', 'wait', 'pay', 'per', 'view', 'dollar'], tags=[154]),
#  TaggedDocument(words=['justify', 'theatrical', 'simulation', 'death', 'camp', 'auschwitz', 'ii-birkenau'], tags=[155]),
#  TaggedDocument(words=['extraordinary', 'faith'], tags=[156]),
#  TaggedDocument(words=['seen', 'film', 'willing', 'champion', 'fallibility', 'human', 'heart'], tags=[157]),
#  TaggedDocument(words=[',', 'sometimes', 'beautiful', 'adaptation'], tags=[158]),
#  TaggedDocument(words=['interesting'], tags=[159]),
#  TaggedDocument(words=['caruso', 'sometimes', 'descends', 'sub-tarantino', 'cuteness', '...', 'part', 'makes', 'sure', 'salton', 'sea', 'works', 'way', 'good', 'noir', ',', 'keeping', 'tight', 'nasty', '.'], tags=[160]),
#  TaggedDocument(words=['overlong', ',', 'bombastic'], tags=[161]),
#  TaggedDocument(words=['derivative', 'hammily'], tags=[162]),
#  TaggedDocument(words=['audacious', ',', 'outrageous', ','], tags=[163]),
#  TaggedDocument(words=['best', 'moments'], tags=[164]),
#  TaggedDocument(words=['disney', 'ransacks', 'archives', 'quick-buck', 'sequel', '.'], tags=[165]),
#  TaggedDocument(words=['final', ',', 'beautiful', 'scene'], tags=[166]),
#  TaggedDocument(words=['movies', 'suck', 'despite', 'flaws', ','], tags=[167]),
#  TaggedDocument(words=['eats', ',', 'meddles', ',', 'argues', ',', 'laughs', ',', 'kibbitzes', 'fights'], tags=[168]),
#  TaggedDocument(words=['problem', 'film', 'whether', 'ambitions', ',', 'laudable', ',', 'justify', 'theatrical', 'simulation', 'death', 'camp', 'auschwitz', 'ii-birkenau', '.'], tags=[169]),
#  TaggedDocument(words=[',', 'compelling'], tags=[170]),
#  TaggedDocument(words=['infectiously'], tags=[171]),
#  TaggedDocument(words=['picture', 'runs', 'mere', '84', 'minutes', ',', "'s", 'glance', '.'], tags=[172]),
#  TaggedDocument(words=['think', 'dog', 'movie'], tags=[173]),
#  TaggedDocument(words=["'s", 'remarkable', 'procession', 'sweeping', 'pictures', 'reinvigorated', 'romance', 'genre', '.'], tags=[174]),
#  TaggedDocument(words=['so-so', 'films', 'could', 'much', 'better'], tags=[175]),
#  TaggedDocument(words=['passable', 'date', 'film'], tags=[176]),
#  TaggedDocument(words=['imax', 'short'], tags=[177]),
#  TaggedDocument(words=['hate', '.'], tags=[178]),
#  TaggedDocument(words=["'s", 'pleasant', 'enough', '--', 'oozing', 'attractive', 'men'], tags=[179]),
#  TaggedDocument(words=['one', 'involved', ',', 'save', 'dash', ',', 'shows', 'slightest', 'aptitude', 'acting'], tags=[180]),
#  TaggedDocument(words=['wildly', 'uneven', 'movie'], tags=[181]),
#  TaggedDocument(words=['pokes', ',', 'provokes', ',', 'takes', 'expressionistic', 'license'], tags=[182]),
#  TaggedDocument(words=['like', 'one', '(', 'spears', "'", ')', 'music', 'videos', 'content', '--', 'except', 'goes', 'least', '90', 'minutes', ',', 'worse', ',', 'pay', 'want', 'see'], tags=[183]),
#  TaggedDocument(words=['color', 'depth', ',', 'rather', 'good', 'time'], tags=[184]),
#  TaggedDocument(words=['silly', ',', 'outrageous', ',', 'ingenious'], tags=[185]),
#  TaggedDocument(words=['able', 'hit', '15-year', 'old', "'re", '100'], tags=[186]),
#  TaggedDocument(words=['story', 'trouble', 'every', 'day', '...', 'sketchy', 'amounts', 'little', 'preliminary', 'notes', 'science-fiction', 'horror', 'film', ',', 'movie', "'s", 'fragmentary', 'narrative', 'style', 'makes', 'piecing', 'story', 'together', 'frustrating', 'difficult', '.'], tags=[187]),
#  TaggedDocument(words=['year', "'s", 'best', 'unpredictable', 'comedy'], tags=[188]),
#  TaggedDocument(words=['starts', 'bad', 'feel', 'like', 'running', 'screaming'], tags=[189]),
#  TaggedDocument(words=['men', 'black', 'ii', 'achieves', 'ultimate', 'insignificance', '--', "'s", 'sci-fi', 'comedy', 'spectacle', 'whiffle-ball', 'epic', '.'], tags=[190]),
#  TaggedDocument(words=['elvira', 'fans', 'could', 'hardly', 'ask', '.'], tags=[191]),
#  TaggedDocument(words=['good', 'one'], tags=[192]),
#  TaggedDocument(words=[',', 'plodding', 'picture'], tags=[193]),
#  TaggedDocument(words=['character', 'dramas', ',', 'never', 'reach', 'satisfying', 'conclusions'], tags=[194]),
#  TaggedDocument(words=['lost', 'translation', 'time'], tags=[195]),
#  TaggedDocument(words=['speak', 'forces', 'ponder', 'anew', 'movie'], tags=[196]),
#  TaggedDocument(words=['enables', 'shafer', 'navigate', 'spaces', 'large', '...', 'small', '...', 'considerable', 'aplomb'], tags=[197]),
#  TaggedDocument(words=['plot', 'cobbled', 'together', 'largely', 'flat', 'uncreative', 'moments'], tags=[198]),
#  TaggedDocument(words=['inane', 'awful'], tags=[199]),
#  TaggedDocument(words=['told', 'scattered', 'fashion'], tags=[200]),
#  TaggedDocument(words=['takes', 'chances', 'bold', 'studio', 'standards'], tags=[201]),
#  TaggedDocument(words=['believe', ',', 'jason', 'actually', 'takes', 'backseat', 'film', 'special', 'effects'], tags=[202]),
#  TaggedDocument(words=['thing', 'fear', '``', 'fear', 'dot', 'com', '``'], tags=[203]),
#  TaggedDocument(words=['whole', 'mess'], tags=[204]),
#  TaggedDocument(words=['manages', 'infuse', 'rocky', 'path', 'sibling', 'reconciliation', 'flashes', 'warmth', 'gentle', 'humor'], tags=[205]),
#  TaggedDocument(words=['working', 'surprisingly', 'sensitive', 'script', 'co-written', 'gianni', 'romoli', '...', 'ozpetek', 'avoids', 'pitfalls', "'d", 'expect', 'potentially', 'sudsy', 'set-up', '.'], tags=[206]),
#  TaggedDocument(words=['résumé', 'loaded', 'credits', 'like', '``', 'girl', 'bar', '#', '3'], tags=[207]),
#  TaggedDocument(words=['enjoy', 'ride'], tags=[208]),
#  TaggedDocument(words=['little', 'add', 'beyond', 'dark', 'visions', 'already', 'relayed', 'superb', 'recent', 'predecessors'], tags=[209]),
#  TaggedDocument(words=[',', 'yes', ',', 'snail-like', 'pacing'], tags=[210]),
#  TaggedDocument(words=['extremely', 'unpleasant', 'film', '.'], tags=[211]),
#  TaggedDocument(words=["n't", 'entirely', 'persuasive', ',', 'give', 'exposure', 'talented', 'performers'], tags=[212]),
#  TaggedDocument(words=['whole', 'affair', ',', 'true', 'story', ',', 'feels', 'incredibly', 'hokey', '...'], tags=[213]),
#  TaggedDocument(words=['things', "'ve", 'seen'], tags=[214]),
#  TaggedDocument(words=['poignant', 'leavened'], tags=[215]),
#  TaggedDocument(words=['breathless', 'anticipation'], tags=[216]),
#  TaggedDocument(words=['significantly', 'better'], tags=[217]),
#  TaggedDocument(words=['predictable', 'tides'], tags=[218]),
#  TaggedDocument(words=['bewilderingly', 'brilliant', 'entertaining'], tags=[219]),
#  TaggedDocument(words=["'s", 'smooth', 'professional'], tags=[220]),
#  TaggedDocument(words=[',', 'unassuming', ',', 'subordinate'], tags=[221]),
#  TaggedDocument(words=['horror'], tags=[222]),
#  TaggedDocument(words=['technically', 'superb', 'film'], tags=[223]),
#  TaggedDocument(words=['positive', 'change', 'tone', 'seems', 'recharged', '.'], tags=[224]),
#  TaggedDocument(words=['pays', 'earnest', 'homage', 'turntablists', 'beat', 'jugglers', ',', 'old', 'schoolers', 'current', 'innovators'], tags=[225]),
#  TaggedDocument(words=['dim'], tags=[226]),
#  TaggedDocument(words=[',', 'vicious', 'absurd'], tags=[227]),
#  TaggedDocument(words=['acts', 'goofy', 'time'], tags=[228]),
#  TaggedDocument(words=['kinetic', 'life', 'teeming', 'even', 'cranky', 'adults', 'may', 'rediscover', 'quivering', 'kid', 'inside'], tags=[229]),
#  TaggedDocument(words=["'s", 'laughable', 'compulsively', 'watchable', ','], tags=[230]),
#  TaggedDocument(words=['merit', '103-minute', 'length'], tags=[231]),
#  TaggedDocument(words=['value', 'respect', 'term', 'epic', 'cinema'], tags=[232]),
#  TaggedDocument(words=['dentist', "'s", 'waiting', 'room'], tags=[233]),
#  TaggedDocument(words=['showing', 'honest', 'emotions'], tags=[234]),
#  TaggedDocument(words=['amazingly', 'lame', '.'], tags=[235]),
#  TaggedDocument(words=['confessions', 'may', 'straightforward', 'bio'], tags=[236]),
#  TaggedDocument(words=['seems', 'disappointingly', 'thin', 'slice', 'lower-class', 'london', 'life', ';', 'despite', 'title', '...', 'amounts', 'surprisingly', 'little'], tags=[237]),
#  TaggedDocument(words=['story', 'bogus'], tags=[238]),
#  TaggedDocument(words=['comic', 'gem', 'delightful', 'derivative', '.'], tags=[239]),
#  TaggedDocument(words=['spare', 'wildlife'], tags=[240]),
#  TaggedDocument(words=['ugly', 'shabby', 'digital', 'photography'], tags=[241]),
#  TaggedDocument(words=['understand', 'difference', 'dumb', 'fun', 'plain', 'dumb'], tags=[242]),
#  TaggedDocument(words=['traditionally', 'structured'], tags=[243]),
#  TaggedDocument(words=['frida', "n't", 'much', 'different', 'many', 'hollywood', 'romance', '.'], tags=[244]),
#  TaggedDocument(words=['point', 'way', 'adventurous', 'indian', 'filmmakers', 'toward', 'crossover', 'nonethnic', 'markets', '.'], tags=[245]),
#  TaggedDocument(words=['worth', 'price', 'admission', '...', '``', 'gory', 'mayhem', '``', 'idea', 'good', 'time'], tags=[246]),
#  TaggedDocument(words=['produced', 'jerry', 'bruckheimer', 'directed', 'joel', 'schumacher', ',', 'reflects', 'worst', 'shallow', 'styles', ':', 'wildly', 'overproduced', ',', 'inadequately', 'motivated', 'every', 'step', 'way', 'demographically', 'targeted', 'please', 'every', 'one', '(', 'one', ')'], tags=[247]),
#  TaggedDocument(words=['carnage'], tags=[248]),
#  TaggedDocument(words=['degraded', ',', 'handheld', 'blair', 'witch', 'video-cam', 'footage'], tags=[249]),
#  TaggedDocument(words=['second', 'fiddle'], tags=[250]),
#  TaggedDocument(words=['folly', 'superficiality'], tags=[251]),
#  TaggedDocument(words=['serves', 'auto-critique', ',', 'clumsiness', 'damning', 'censure', '.'], tags=[252]),
#  TaggedDocument(words=['tedious', 'norwegian', 'offering', 'somehow', 'snagged', 'oscar', 'nomination', '.'], tags=[253]),
#  TaggedDocument(words=[',', 'esther', 'kahn', 'unusual', 'unfortunately', 'also', 'irritating', '.'], tags=[254]),
#  TaggedDocument(words=['stylish', 'exercise'], tags=[255]),
#  TaggedDocument(words=['halfway', 'picture', 'beginning', 'hate'], tags=[256]),
#  TaggedDocument(words=['setup', 'easy', 'borders', 'facile'], tags=[257]),
#  TaggedDocument(words=['thoroughly', 'awful', 'movie'], tags=[258]),
#  TaggedDocument(words=['takes', 'hold', 'grips', 'hard'], tags=[259]),
#  TaggedDocument(words=['look', 'smeary', 'blurry', ',', 'point', 'distraction'], tags=[260]),
#  TaggedDocument(words=['picture', "'s", 'fascinating', 'byways'], tags=[261]),
#  TaggedDocument(words=['guns', ',', 'cheatfully', 'filmed', 'martial', 'arts', ',', 'disintegrating', 'bloodsucker', 'computer', 'effects', 'jagged', 'camera', 'moves'], tags=[262]),
#  TaggedDocument(words=['breezy', ',', 'distracted', 'rhythms'], tags=[263]),
#  TaggedDocument(words=['mess'], tags=[264]),
#  TaggedDocument(words=['evanescent', ',', 'seamless', 'sumptuous', 'stream'], tags=[265]),
#  TaggedDocument(words=['slick', 'manufactured', 'claim', 'street', 'credibility', '.'], tags=[266]),
#  TaggedDocument(words=['take', 'care', 'nicely', 'performed', 'quintet', 'actresses', ','], tags=[267]),
#  TaggedDocument(words=['valuable', 'messages'], tags=[268]),
#  TaggedDocument(words=['small', 'part', 'thanks', 'lau'], tags=[269]),
#  TaggedDocument(words=['two', 'guys', 'desperately', 'want', 'quentin', 'tarantino', 'grow'], tags=[270]),
#  TaggedDocument(words=['new', 'plot', 'conceptions'], tags=[271]),
#  TaggedDocument(words=['essentially', 'collection', 'bits', '--'], tags=[272]),
#  TaggedDocument(words=["n't", 'bode', 'well', 'rest'], tags=[273]),
#  TaggedDocument(words=['elevated', '--', 'kind', 'movie'], tags=[274]),
#  TaggedDocument(words=['usual', 'worst'], tags=[275]),
#  TaggedDocument(words=['hugh', 'grant', ',', 'good', 'line', 'charm'], tags=[276]),
#  TaggedDocument(words=['arrive', 'early', 'stay', 'late'], tags=[277]),
#  TaggedDocument(words=['pan-american', 'movie', ',', 'moments', 'genuine', 'insight', 'urban', 'heart', '.'], tags=[278]),
#  TaggedDocument(words=['could', 'used', 'two', 'hours', 'better', 'watching', 'john', 'malkovich', '.'], tags=[279]),
#  TaggedDocument(words=['shot', 'artful', ',', 'watery', 'tones', 'blue', ',', 'green', 'brown'], tags=[280]),
#  TaggedDocument(words=['unorthodox', 'little', 'film', 'noir', 'organized', 'crime', 'story', 'includes', 'one', 'strangest'], tags=[281]),
#  TaggedDocument(words=['considerable', 'aplomb'], tags=[282]),
#  TaggedDocument(words=['acted', 'diane', 'lane', 'richard', 'gere', '.'], tags=[283]),
#  TaggedDocument(words=['scant'], tags=[284]),
#  TaggedDocument(words=['admittedly', 'middling', 'film'], tags=[285]),
#  TaggedDocument(words=['ludicrous'], tags=[286]),
#  TaggedDocument(words=['rock', "'s", 'fighting', 'skills', 'line', 'steven', 'seagal'], tags=[287]),
#  TaggedDocument(words=['rich', 'full'], tags=[288]),
#  TaggedDocument(words=['warm', 'water', 'red', 'bridge', 'celebration', 'feminine', 'energy', ',', 'tribute', 'power', 'women', 'heal', '.'], tags=[289]),
#  TaggedDocument(words=['uses', 'sensational', ',', 'real-life', '19th-century', 'crime', 'metaphor'], tags=[290]),
#  TaggedDocument(words=[',', 'home', 'movie', 'leave', 'wanting', ',', 'mention', 'leaving', 'laughs', 'smile', 'face', '.'], tags=[291]),
#  TaggedDocument(words=[',', 'film', 'retains', 'ambiguities', 'make', 'well', 'worth', 'watching', '.'], tags=[292]),
#  TaggedDocument(words=['ultra-cheesy', 'dialogue'], tags=[293]),
#  TaggedDocument(words=['added', 'depth', 'resonance'], tags=[294]),
#  TaggedDocument(words=['sensational'], tags=[295]),
#  TaggedDocument(words=['huge-screen', 'format', 'make', 'old-fashioned', 'nature', 'film', 'educates', 'viewers', 'words', 'pictures', 'entertaining'], tags=[296]),
#  TaggedDocument(words=['handsome', 'unfulfilling', 'suspense', 'drama'], tags=[297]),
#  TaggedDocument(words=["'s", 'good', 'either', '.'], tags=[298]),
#  TaggedDocument(words=['charmless'], tags=[299]),
#  TaggedDocument(words=['makes', 'unusual', 'pleasantly', 'haunting', 'debut', 'behind', 'camera', '.'], tags=[300]),
#  TaggedDocument(words=['fine', ',', 'rousing', ',', 'g-rated', 'family', 'film', ',', 'aimed', 'mainly', 'little', 'kids', 'plenty', 'entertainment', 'value', 'keep', 'grown-ups', 'squirming', 'seats', '.'], tags=[301]),
#  TaggedDocument(words=['everything', 'girls', 'ca', "n't", 'swim', ',', 'even', 'passages', 'sensitive', 'observation', ',', 'feels', 'secondhand', ',', 'familiar', '--', 'good', 'way', '.'], tags=[302]),
#  TaggedDocument(words=['cast', 'spot'], tags=[303]),
#  TaggedDocument(words=['ugly', 'digital', 'video'], tags=[304]),
#  TaggedDocument(words=['love', 'players', 'brings', 'fore', 'gifted', 'no-nonsense', 'human', 'beings', 'still-inestimable', 'contribution', 'made', 'shared', 'history'], tags=[305]),
#  TaggedDocument(words=['rather', 'choppy'], tags=[306]),
#  TaggedDocument(words=['becomes', 'one', 'dumb', 'high', 'school', 'comedy', 'sex', 'gags', 'prom', 'dates'], tags=[307]),
#  TaggedDocument(words=['demands', 'receives', 'excellent', 'performances'], tags=[308]),
#  TaggedDocument(words=['xxx', 'blast', 'adrenalin', ','], tags=[309]),
#  TaggedDocument(words=['pure', 'escapism'], tags=[310]),
#  TaggedDocument(words=['create', 'film', "'s", 'merely', 'kicking', 'undead', '***'], tags=[311]),
#  TaggedDocument(words=['love', 'culture'], tags=[312]),
#  TaggedDocument(words=['worse', ':'], tags=[313]),
#  TaggedDocument(words=['horrifying'], tags=[314]),
#  TaggedDocument(words=['mourns', 'tragedies', 'private'], tags=[315]),
#  TaggedDocument(words=['action', 'scenes', 'poorly', 'delivered'], tags=[316]),
#  TaggedDocument(words=["'s", 'bad'], tags=[317]),
#  TaggedDocument(words=['bad'], tags=[318]),
#  TaggedDocument(words=[',', '84', 'minutes', 'short'], tags=[319]),
#  TaggedDocument(words=['dabbles', 'around', ',', 'never', 'gaining', 'much', 'momentum'], tags=[320]),
#  TaggedDocument(words=['masterpiece'], tags=[321]),
#  TaggedDocument(words=['lot', 'casting', 'juliette', 'binoche', 'sand', ',', 'brings', 'role', 'pale', ',', 'dark', 'beauty', 'characteristic', 'warmth'], tags=[322]),
#  TaggedDocument(words=["n't", 'leave', 'much', '.'], tags=[323]),
#  TaggedDocument(words=['good', 'acting'], tags=[324]),
#  TaggedDocument(words=['like', 'jaglom', "'s", 'films', ',', 'honestly', 'affecting'], tags=[325]),
#  TaggedDocument(words=['marivaux', "'s", 'rhythms', ',', 'mira', 'sorvino', "'s", 'limitations', 'classical', 'actress'], tags=[326]),
#  TaggedDocument(words=['less', 'successful', 'levels'], tags=[327]),
#  TaggedDocument(words=["'s", 'still', 'quite', 'worth', 'seeing'], tags=[328]),
#  TaggedDocument(words=['intelligent', 'moving', '.'], tags=[329]),
#  TaggedDocument(words=['appears', 'miserable', 'throughout', 'swaggers', 'scenes'], tags=[330]),
#  TaggedDocument(words=['men'], tags=[331]),
#  TaggedDocument(words=['accomplish', 'sequels'], tags=[332]),
#  TaggedDocument(words=['clunky', 'tv-movie', 'approach', 'detailing', 'chapter', 'life', 'celebrated', 'irish', 'playwright', ',', 'poet', 'drinker'], tags=[333]),
#  TaggedDocument(words=["'m", 'sure', 'half', 'dragonfly', 'worse', ':', 'part', 'nothing', "'s", 'happening', ',', 'part', 'something', "'s", 'happening'], tags=[334]),
#  TaggedDocument(words=['exhilarating', ',', 'funny', 'fun', '.'], tags=[335]),
#  TaggedDocument(words=['bound', 'appeal', 'women', 'looking', 'howlingly', 'trashy', 'time'], tags=[336]),
#  TaggedDocument(words=[',', 'never', 'quite', 'makes', 'grade', 'tawdry', 'trash', '.'], tags=[337]),
#  TaggedDocument(words=['right', 'stuff', 'silly', 'summer', 'entertainment', 'enough', 'laughs', 'sustain', 'interest', 'end', '.'], tags=[338]),
#  TaggedDocument(words=['endearing', ',', 'caring'], tags=[339]),
#  TaggedDocument(words=['seagal', ',', 'looks', 'like', 'danny', 'aiello', 'days'], tags=[340]),
#  TaggedDocument(words=['enactments', ',', 'however', 'fascinating', 'may', 'history', ',', 'crude', 'serve', 'work', 'especially', 'well', '.'], tags=[341]),
#  TaggedDocument(words=['everything', 'ambitious', 'comic', 'escapade', 'works', ',', 'coppola', ',', 'along', 'sister', ',', 'sofia', ',', 'real', 'filmmaker'], tags=[342]),
#  TaggedDocument(words=['dehumanizing', 'ego-destroying', 'process'], tags=[343]),
#  TaggedDocument(words=['taboo', 'subject', 'matter'], tags=[344]),
#  TaggedDocument(words=['see'], tags=[345]),
#  TaggedDocument(words=['utterly', 'incompetent', 'conclusion'], tags=[346]),
#  TaggedDocument(words=['always', 'part', 'part', 'wilde', "'s", 'droll', 'whimsy', 'helps', '``', 'earnest', '``', 'overcome', 'weaknesses', 'parker', "'s", 'creative', 'interference', '...'], tags=[347]),
#  TaggedDocument(words=['find', 'rooting', 'gai', "'s", 'character', 'avoid', 'fate', 'befallen', 'every', 'carmen'], tags=[348]),
#  TaggedDocument(words=['run', 'cover'], tags=[349]),
#  TaggedDocument(words=['low', 'budget'], tags=[350]),
#  TaggedDocument(words=['deceptively', 'casual', 'ode'], tags=[351]),
#  TaggedDocument(words=['walked', 'muttering', 'words', 'like', '``', 'horrible', '``', '``', 'terrible', ',', '``'], tags=[352]),
#  TaggedDocument(words=['help', 'chicago', 'make', 'transition', 'stage', 'screen', 'considerable', 'appeal', 'intact'], tags=[353]),
#  TaggedDocument(words=['ellen', 'pompeo', 'sitting', 'next', 'ride'], tags=[354]),
#  TaggedDocument(words=['giant', 'step', 'backward'], tags=[355]),
#  TaggedDocument(words=['true', 'fans'], tags=[356]),
#  TaggedDocument(words=['copies'], tags=[357]),
#  TaggedDocument(words=['quite', 'rich', 'exciting'], tags=[358]),
#  TaggedDocument(words=['luminous', 'interviews', 'amazingly', 'evocative', 'film', 'three', 'decades', 'ago'], tags=[359]),
#  TaggedDocument(words=['lynch', ',', 'jeunet', ',', 'von', 'trier', 'failing', 'find', 'spark'], tags=[360]),
#  TaggedDocument(words=[',', 'ca', "n't", 'help', 'get', 'caught', 'thrill', 'company', "'s", 'astonishing', 'growth', '.'], tags=[361]),
#  TaggedDocument(words=['frozen', 'tundra', 'soap', 'opera'], tags=[362]),
#  TaggedDocument(words=['showdown'], tags=[363]),
#  TaggedDocument(words=['simply', 'overdone'], tags=[364]),
#  TaggedDocument(words=['greatly'], tags=[365]),
#  TaggedDocument(words=['free'], tags=[366]),
#  TaggedDocument(words=['intriguing', 'species'], tags=[367]),
#  TaggedDocument(words=['try', 'evade'], tags=[368]),
#  TaggedDocument(words=['scherfig', ',', 'successful', 'career', 'tv'], tags=[369]),
#  TaggedDocument(words=['watching', 'leaves', 'giddy'], tags=[370]),
#  TaggedDocument(words=['beautifully', 'acted', 'directed', ',', "'s", 'clear', 'washington', 'certainly', 'new', 'career', 'ahead', 'chooses', '.'], tags=[371]),
#  TaggedDocument(words=['far', 'tamer'], tags=[372]),
#  TaggedDocument(words=['outrageously', 'creative', 'action'], tags=[373]),
#  TaggedDocument(words=['purely', 'enjoyable', 'satisfying', 'evenings'], tags=[374]),
#  TaggedDocument(words=['never', 'question', 'things', 'turn'], tags=[375]),
#  TaggedDocument(words=['open', 'new', 'wounds'], tags=[376]),
#  TaggedDocument(words=['despite', 'suffering', 'sense-of-humour', 'failure'], tags=[377]),
#  TaggedDocument(words=['story'], tags=[378]),
#  TaggedDocument(words=['addition', 'hoffman', "'s", 'powerful', 'acting', 'clinic'], tags=[379]),
#  TaggedDocument(words=['right', 'stuff'], tags=[380]),
#  TaggedDocument(words=['wonderful', 'cinematography', 'naturalistic', 'acting'], tags=[381]),
#  TaggedDocument(words=['high-concept', 'films'], tags=[382]),
#  TaggedDocument(words=['sleepwalk', 'vulgarities', 'sequel', 'refuse'], tags=[383]),
#  TaggedDocument(words=['reason'], tags=[384]),
#  TaggedDocument(words=['film', 'confusing', 'one', 'level', 'another', ',', 'making', 'ararat', 'far', 'demanding', 'needs', '.'], tags=[385]),
#  TaggedDocument(words=['invigorating', ',', 'surreal', ',', 'resonant'], tags=[386]),
#  TaggedDocument(words=['chateau', ',', 'sense', 'light-heartedness', ',', 'makes', 'attractive', 'throughout'], tags=[387]),
#  TaggedDocument(words=['passion', 'material'], tags=[388]),
#  TaggedDocument(words=['maybe', 'formula', 'filmmaking', ',', "'s", 'nothing', 'wrong', 'film', 'well-crafted', 'one', '.'], tags=[389]),
#  TaggedDocument(words=['movie', 'ca', "n't", 'get', 'sufficient', 'distance', 'leroy', "'s"], tags=[390]),
#  TaggedDocument(words=['romanticized', 'rendering'], tags=[391]),
#  TaggedDocument(words=['terrific', 'rachel'], tags=[392]),
#  TaggedDocument(words=['special', 'effects', 'run', 'gamut', 'cheesy', 'cheesier', 'cheesiest'], tags=[393]),
#  TaggedDocument(words=['worst', 'film', 'man', 'made', 'women', 'since', 'valley', 'dolls'], tags=[394]),
#  TaggedDocument(words=['come', ',', 'already', 'recycled', 'times', "'d", 'care', 'count'], tags=[395]),
#  TaggedDocument(words=['awe'], tags=[396]),
#  TaggedDocument(words=['joyous', 'romp', 'film', '.'], tags=[397]),
#  TaggedDocument(words=['nonstop', 'hoot'], tags=[398]),
#  TaggedDocument(words=[',', 'partisans', 'sabotage'], tags=[399]),
#  TaggedDocument(words=['gory', 'scenes', 'torture', 'self-mutilation'], tags=[400]),
#  TaggedDocument(words=['recent', 'argentine', 'film', 'son', 'bride', 'reminded', 'us', 'feel-good', 'movie', 'still', 'show', 'real', 'heart'], tags=[401]),
#  TaggedDocument(words=['ub', 'equally', 'spoofs', 'celebrates', 'outre', 'aspects', '`', 'black', 'culture', "'", 'dorkier', 'aspects', '`', 'white', 'culture', ',', "'", 'even', 'points', 'inseparable', 'two', '.'], tags=[402]),
#  TaggedDocument(words=['package', 'fascinating', '--', 'timely', '--', 'content', 'comes', 'wrapped', 'disappointingly', 'generic', '.'], tags=[403]),
#  TaggedDocument(words=['obscenely', 'bad', 'dark', 'comedy', ',', 'crass'], tags=[404]),
#  TaggedDocument(words=['naomi', 'watts', 'terrific', 'rachel', ';', 'petite', 'frame', 'vulnerable', 'persona', 'emphasising', 'plight', 'isolation'], tags=[405]),
#  TaggedDocument(words=['exciting'], tags=[406]),
#  TaggedDocument(words=['schticky'], tags=[407]),
#  TaggedDocument(words=['best', 'way'], tags=[408]),
#  TaggedDocument(words=['flamboyant', 'female', 'comics'], tags=[409]),
#  TaggedDocument(words=['squareness', 'would', 'make', 'darling', 'many', 'kids-and-family-oriented', 'cable', 'channel'], tags=[410]),
#  TaggedDocument(words=['(', 'less', 'movie', ')', 'appalling', ',', 'odoriferous', 'thing', '...'], tags=[411]),
#  TaggedDocument(words=['film', 'special'], tags=[412]),
#  TaggedDocument(words=['amazing', 'spider-man'], tags=[413]),
#  TaggedDocument(words=['stomach-turning', 'violence'], tags=[414]),
#  TaggedDocument(words=['could', 'use', 'little', 'humanity'], tags=[415]),
#  TaggedDocument(words=['everything'], tags=[416]),
#  TaggedDocument(words=['acquires', 'undeniable', 'entertainment', 'value', 'slight', ',', 'pale', 'mr.', 'broomfield', 'continues', 'force', 'people', 'situations', 'would', 'make', 'lesser', 'men', 'run', 'cover', '.'], tags=[417]),
#  TaggedDocument(words=['slow-moving', 'police-procedural', 'thriller'], tags=[418]),
#  TaggedDocument(words=['bad', 'idea', 'frame', 'one'], tags=[419]),
#  TaggedDocument(words=['terrific', ',', 'sweaty-palmed', 'fun'], tags=[420]),
#  TaggedDocument(words=['funny', 'joke'], tags=[421]),
#  TaggedDocument(words=['volletta', 'wallace', "'s", 'maternal', 'fury'], tags=[422]),
#  TaggedDocument(words=['complex', 'story'], tags=[423]),
#  TaggedDocument(words=['atop', 'wooden', 'dialogue'], tags=[424]),
#  TaggedDocument(words=['progresses', 'low-key', 'manner', 'risks', 'monotony'], tags=[425]),
#  TaggedDocument(words=['burns', "'s", 'strongest', 'film', 'since', 'brothers', 'mcmullen'], tags=[426]),
#  TaggedDocument(words=['ca', "n't", 'miss'], tags=[427]),
#  TaggedDocument(words=['dover', 'kosashvili', "'s", 'outstanding', 'feature', 'debut', 'potent'], tags=[428]),
#  TaggedDocument(words=['best', 'short', 'story', 'writing'], tags=[429]),
#  TaggedDocument(words=['seeks', 'excitement', 'manufactured', 'high', 'drama'], tags=[430]),
#  TaggedDocument(words=['feeble', 'comedy', '.'], tags=[431]),
#  TaggedDocument(words=['insult', 'every', 'family'], tags=[432]),
#  TaggedDocument(words=['essentially', 'empty'], tags=[433]),
#  TaggedDocument(words=['film', "'s", 'problems'], tags=[434]),
#  TaggedDocument(words=['makes', 'big', 'fat', 'greek', 'wedding', 'look', 'like', 'apartheid', 'drama'], tags=[435]),
#  TaggedDocument(words=['even', 'half', 'interest', '.'], tags=[436]),
#  TaggedDocument(words=['never', 'achieve', 'popularity', 'big', 'fat', 'greek', 'wedding'], tags=[437]),
#  TaggedDocument(words=['``', 'auto', 'focus', '``', 'works', 'unusual', 'biopic', 'document', 'male', 'swingers', 'playboy', 'era'], tags=[438]),
#  TaggedDocument(words=['right', ',', "'re", 'merely', 'signposts', 'marking', 'slow', ',', 'lingering', 'death', 'imagination', '.'], tags=[439]),
#  TaggedDocument(words=['appealing', 'character', 'quirks', 'forgive', 'still', 'serious', 'problem'], tags=[440]),
#  TaggedDocument(words=['often', 'lingers', 'long', 'irrelevant', 'engaging', ',', 'gradually', 'turns', 'time', '?'], tags=[441]),
#  TaggedDocument(words=['energy', 'takes', 'describe', 'bad'], tags=[442]),
#  TaggedDocument(words=['wait', 'see', '.'], tags=[443]),
#  TaggedDocument(words=['could', 'easily', 'called', 'best', 'korean', 'film', '2002'], tags=[444]),
#  TaggedDocument(words=['largest-ever', 'historical', 'canvas'], tags=[445]),
#  TaggedDocument(words=['solid', 'cast', ',', 'assured', 'direction', 'complete', 'lack', 'modern', 'day', 'irony', '.'], tags=[446]),
#  TaggedDocument(words=['comatose', 'ballerinas'], tags=[447]),
#  TaggedDocument(words=['oh-so-important'], tags=[448]),
#  TaggedDocument(words=['road', ',', 'thematic', 'ironies', 'obvious', 'sexual', 'politics', 'smug'], tags=[449]),
#  TaggedDocument(words=['formulaic', 'equations'], tags=[450]),
#  TaggedDocument(words=["'s", 'work', ',', 'humor', ',', 'warmth', ',', 'intelligence', ',', 'captures', 'life', 'interestingly', 'lived'], tags=[451]),
#  TaggedDocument(words=['deserve', 'passing', 'grade'], tags=[452]),
#  TaggedDocument(words=["'re", 'gon', 'na', 'like', 'movie', '.'], tags=[453]),
#  TaggedDocument(words=['simply', 'stupid', ',', 'irrelevant'], tags=[454]),
#  TaggedDocument(words=['weaves', 'elements', 'plot', 'powerfully', 'evocative', 'mood', 'combining', 'heated', 'sexuality', 'haunting', 'sense', 'malaise', '.'], tags=[455]),
#  TaggedDocument(words=['heavy-handed', 'indictment', 'parental', 'failings'], tags=[456]),
#  TaggedDocument(words=['felt', 'performances', 'across', 'board', '.'], tags=[457]),
#  TaggedDocument(words=['seem', 'weird', 'distanced'], tags=[458]),
#  TaggedDocument(words=['finally', 'made', 'movie', "n't", 'offensive'], tags=[459]),
#  TaggedDocument(words=['casual', 'fun'], tags=[460]),
#  TaggedDocument(words=['plodding', 'mess'], tags=[461]),
#  TaggedDocument(words=['weird', 'thing', 'santa', 'clause', '2', ',', 'purportedly', 'children', "'s", 'movie', ',', 'nothing', 'engage', 'children', 'emotionally', '.'], tags=[462]),
#  TaggedDocument(words=['film', "'s", 'intimate', 'camera', 'work'], tags=[463]),
#  TaggedDocument(words=["'ll", 'find', 'wishing', 'another', 'movie', '.'], tags=[464]),
#  TaggedDocument(words=['dishonesty'], tags=[465]),
#  TaggedDocument(words=['bestial'], tags=[466]),
#  TaggedDocument(words=['loose', 'collection', 'not-so-funny', 'gags', ',', 'scattered', 'moments', 'lazy', 'humor'], tags=[467]),
#  TaggedDocument(words=[',', 'prove', 'distressing', 'suspenseful', '.'], tags=[468]),
#  TaggedDocument(words=['crackles'], tags=[469]),
#  TaggedDocument(words=['fairly', 'revealing', 'study', 'two', 'main', 'characters'], tags=[470]),
#  TaggedDocument(words=['high', 'drama', ',', 'disney-style'], tags=[471]),
#  TaggedDocument(words=['may', 'genial', 'ingenious', ',', 'gets', 'job', 'done', '.'], tags=[472]),
#  TaggedDocument(words=[',', 'good', 'action', ',', 'good', 'acting', ',', 'good', 'dialogue', ',', 'good', 'pace', ',', 'good', 'cinematography', '.'], tags=[473]),
#  TaggedDocument(words=['bully', 'husband'], tags=[474]),
#  TaggedDocument(words=['gaghan', '...', 'thrown', 'every', 'suspenseful', 'cliché', 'book', 'nonsensical', 'story', '.'], tags=[475]),
#  TaggedDocument(words=['darker', 'elements', 'misogyny', 'unprovoked', 'violence', 'suffocate', 'illumination', 'created', 'two', 'daughters'], tags=[476]),
#  TaggedDocument(words=['oozing', ',', 'chilling', 'heart-warming'], tags=[477]),
#  TaggedDocument(words=['stale', 'retread'], tags=[478]),
#  TaggedDocument(words=['filming', 'teeming', 'life', 'reefs'], tags=[479]),
#  TaggedDocument(words=['already', 'thin', 'story', 'boils', 'surviving', 'invaders', 'seeking', 'existent', 'anti-virus', '.'], tags=[480]),
#  TaggedDocument(words=['quite', 'endearing', '.'], tags=[481]),
#  TaggedDocument(words=['fewer', 'gags', 'break', 'tedium'], tags=[482]),
#  TaggedDocument(words=['overbearing'], tags=[483]),
#  TaggedDocument(words=['deep', 'deceptions'], tags=[484]),
#  TaggedDocument(words=['things', 'turn', 'okay'], tags=[485]),
#  TaggedDocument(words=['paranoid', 'claustrophobia', 'submarine', 'movie', 'unsettling', 'spookiness', 'supernatural'], tags=[486]),
#  TaggedDocument(words=['grand'], tags=[487]),
#  TaggedDocument(words=['good-natured', 'fun', 'found', 'films', 'like', 'tremors'], tags=[488]),
#  TaggedDocument(words=['betters'], tags=[489]),
#  TaggedDocument(words=['transfixes', 'audience'], tags=[490]),
#  TaggedDocument(words=['moving', 'important'], tags=[491]),
#  TaggedDocument(words=['dope'], tags=[492]),
#  TaggedDocument(words=['avid', 'interest'], tags=[493]),
#  TaggedDocument(words=['blessed', 'two', 'fine', ',', 'nuanced', 'lead', 'performances'], tags=[494]),
#  TaggedDocument(words=['true', 'star'], tags=[495]),
#  TaggedDocument(words=['hampered', '--', ',', 'paralyzed', '--', 'self-indulgent', 'script', '...'], tags=[496]),
#  TaggedDocument(words=['expressly', 'idiots', "n't", 'care', 'kind', 'sewage', 'shovel', 'mental', 'gullets', 'simulate', 'sustenance', '.'], tags=[497]),
#  TaggedDocument(words=['haunting', '...', '(', "'s", ')', 'punk', 'rock', 'music', 'used', ',', 'video', 'medium', 'could', 'use', ':', 'spirit', ',', 'perception', ',', 'conviction'], tags=[498]),
#  TaggedDocument(words=['nurses', 'plot', 'holes', 'gaping', 'enough', 'pilot', 'entire', 'olympic', 'swim', 'team'], tags=[499]),
#  TaggedDocument(words=["'s", 'charming', 'well', 'acted'], tags=[500]),
#  TaggedDocument(words=['bad', 'blend'], tags=[501]),
#  TaggedDocument(words=['guy-in-a-dress', 'genre'], tags=[502]),
#  TaggedDocument(words=['director', 'claude', 'chabrol', 'become', 'master', 'innuendo', '.'], tags=[503]),
#  TaggedDocument(words=['riveting'], tags=[504]),
#  TaggedDocument(words=['excruciatingly', 'unfunny', 'pitifully', 'unromantic', '.'], tags=[505]),
#  TaggedDocument(words=['war', 'movies'], tags=[506]),
#  TaggedDocument(words=['inuit', 'masterpiece'], tags=[507]),
#  TaggedDocument(words=['oscar'], tags=[508]),
#  TaggedDocument(words=['cliché-laden', 'screenplay'], tags=[509]),
#  TaggedDocument(words=['girlfriends', 'bad', ',', 'wives', 'worse'], tags=[510]),
#  TaggedDocument(words=['provide', 'much', 'insight'], tags=[511]),
#  TaggedDocument(words=[',', 'easy', 'bored', 'abc', "'s", ','], tags=[512]),
#  TaggedDocument(words=['wish'], tags=[513]),
#  TaggedDocument(words=['fluid', 'mesmerizing'], tags=[514]),
#  TaggedDocument(words=['...', 'vivid', ',', 'thoughtful', ',', 'unapologetically', 'raw', 'coming-of-age', 'tale', 'full', 'sex', ',', 'drugs', 'rock', "'", 'n', "'", 'roll', '.'], tags=[515]),
# ...
#  TaggedDocument(words=['daring'], tags=[836]),
#  TaggedDocument(words=['wo', "n't", 'feel', 'cheated', 'high', 'infidelity', 'unfaithful', '.'], tags=[837]),
#  TaggedDocument(words=['haute'], tags=[838]),
#  TaggedDocument(words=['convey', 'strong', 'sense', 'girls', "'", 'environment', '.'], tags=[839]),
#  TaggedDocument(words=['ugly'], tags=[840]),
#  TaggedDocument(words=['journey', 'spanning', 'nearly', 'three', 'decades', 'bittersweet', 'camaraderie', 'history', ',', 'feel', 'truly', 'know', 'makes', 'holly', 'marina', 'tick'], tags=[841]),
#  TaggedDocument(words=['insight'], tags=[842]),
#  TaggedDocument(words=['well-intentioned', 'effort', "'s", 'still', 'burdened', 'actor', "'s", 'offbeat', 'sensibilities', 'earnest', 'emotional', 'core', 'emerge', 'degree', 'accessibility', '.'], tags=[843]),
#  TaggedDocument(words=['passionate', ',', 'tumultuous', 'affair'], tags=[844]),
#  TaggedDocument(words=['kind', 'under-inspired', ',', 'overblown', 'enterprise', 'gives', 'hollywood', 'sequels', 'bad', 'name'], tags=[845]),
#  TaggedDocument(words=['enjoyable', 'experience', '.'], tags=[846]),
#  TaggedDocument(words=["'ve", 'interesting', '--', ',', 'dare', 'say', ',', 'thematically', 'complex', '--', 'bowel', 'movements', 'long-on-the-shelf', ',', 'point-and-shoot', 'exercise', 'gimmicky', 'crime', 'drama', '.'], tags=[847]),
#  TaggedDocument(words=['greater', 'attention', 'parents', '--', 'particularly', 'fateful', 'fathers', '--', 'emotional', 'evolution', 'two', 'bewitched', 'adolescents', '.'], tags=[848]),
#  TaggedDocument(words=['well', 'cram', 'earplugs'], tags=[849]),
#  TaggedDocument(words=['simply', 'tired'], tags=[850]),
#  TaggedDocument(words=["'s", 'little', 'nuances', 'perhaps', 'escape', 'director', 'mark', 'romanek', "'s", 'self-conscious', 'scrutiny', 'happen', ',', 'finally', 'get', 'skin'], tags=[851]),
#  TaggedDocument(words=['convincing', 'radiant'], tags=[852]),
#  TaggedDocument(words=['smart', 'dark', '-'], tags=[853]),
#  TaggedDocument(words=['emaciated', 'flick'], tags=[854]),
#  TaggedDocument(words=['jim', 'brown', 'treats', 'women', '--', 'dumb', ',', 'credulous', ',', 'unassuming', ',', 'subordinate', 'subjects'], tags=[855]),
#  TaggedDocument(words=['point', 'things', 'explode', 'flame'], tags=[856]),
#  TaggedDocument(words=['jolts', 'laughs', 'audience'], tags=[857]),
#  TaggedDocument(words=['heralds', 'something', 'special'], tags=[858]),
#  TaggedDocument(words=["n't", 'escaped', 'rut', 'dug', 'last', 'one'], tags=[859]),
#  TaggedDocument(words=['perfect', 'performance'], tags=[860]),
#  TaggedDocument(words=['cinema', 'verite', 'speculation', 'assassination', 'john', 'f.', 'kennedy', 'may', 'inspired', 'blair', 'witch', ',', 'takes', 'techniques', 'fresh', 'territory', 'film', 'never', 'feels', 'derivative'], tags=[861]),
#  TaggedDocument(words=['unsuccessful', 'attempt', 'movie'], tags=[862]),
#  TaggedDocument(words=['sometimes', 'confusing'], tags=[863]),
#  TaggedDocument(words=['superlative'], tags=[864]),
#  TaggedDocument(words=['buy', 'soundtrack'], tags=[865]),
#  TaggedDocument(words=["'s", 'sharply', 'comic', 'surprisingly', 'touching', ','], tags=[866]),
#  TaggedDocument(words=['soap-opera', 'quality', 'twist', 'last', '20', 'minutes', '...', 'almost', 'puts', 'kibosh', 'otherwise', 'sumptuous', 'work', 'b-movie', 'imagination', '.'], tags=[867]),
#  TaggedDocument(words=['change', 'hackneyed', 'concepts', 'comes', 'dreaming', 'romantic', 'comedies'], tags=[868]),
#  TaggedDocument(words=['folly', 'superficiality'], tags=[869]),
#  TaggedDocument(words=['lumbering', 'load'], tags=[870]),
#  TaggedDocument(words=['95-minute', 'commercial', 'nba', 'properties'], tags=[871]),
#  TaggedDocument(words=['though', 'many', 'guys', 'less', 'adorable'], tags=[872]),
#  TaggedDocument(words=['peels', 'layers', 'character', 'may', 'well', 'existed', 'paper', '.'], tags=[873]),
#  TaggedDocument(words=['deadly', 'dull'], tags=[874]),
#  TaggedDocument(words=['inferior'], tags=[875]),
#  TaggedDocument(words=['big-hearted', 'frequently'], tags=[876]),
#  TaggedDocument(words=['striking', 'deep', 'chords', 'sadness'], tags=[877]),
#  TaggedDocument(words=['laughs', 'aplenty'], tags=[878]),
#  TaggedDocument(words=['schaeffer', "n't", 'film', ',', 'may', 'works', 'well', '.'], tags=[879]),
#  TaggedDocument(words=['loud', ',', 'ugly', ',', 'irritating', 'movie'], tags=[880]),
#  TaggedDocument(words=['impressive', 'sights', 'sounds', 'wondrous', 'beats', 'world', 'offer'], tags=[881]),
#  TaggedDocument(words=['scorpion', 'king', 'ably'], tags=[882]),
#  TaggedDocument(words=['make', 'pretty', 'good', 'team'], tags=[883]),
#  TaggedDocument(words=['lags', 'badly', 'middle', 'lurches', 'not-very-funny', 'comedy', ',', 'unconvincing', 'dramatics', 'last-minute', 'action', 'strongly', 'reminiscent', 'run', 'lola', 'run'], tags=[884]),
#  TaggedDocument(words=['great', 'combination', 'act', 'narrator', ',', 'jewish', 'grandmother', 'subject', '--', 'taking', 'us', 'film', 'part', 'biography', ',', 'part', 'entertainment', 'part', 'history', '.'], tags=[885]),
#  TaggedDocument(words=['bill', 'plympton', ',', 'animation', 'master'], tags=[886]),
#  TaggedDocument(words=['impossible', 'task'], tags=[887]),
#  TaggedDocument(words=['good', 'way'], tags=[888]),
#  TaggedDocument(words=['watch', 'makes', 'time', 'go', 'faster', 'rather'], tags=[889]),
#  TaggedDocument(words=['best', 'pictures'], tags=[890]),
#  TaggedDocument(words=['lack', 'idol', "'s", 'energy', 'passion', 'detail'], tags=[891]),
#  TaggedDocument(words=['church', 'meetings'], tags=[892]),
#  TaggedDocument(words=['creating', 'emotionally', 'complex', ',', 'dramatically', 'satisfying', 'heroine'], tags=[893]),
#  TaggedDocument(words=['compassionate'], tags=[894]),
#  TaggedDocument(words=['find', 'characters', "'", 'foibles', 'timeless', 'unique', 'perspective'], tags=[895]),
#  TaggedDocument(words=['hugely', 'entertaining', 'start', 'finish', ',', 'featuring', 'fall', 'grace', 'still', 'leaves', 'shockwaves'], tags=[896]),
#  TaggedDocument(words=['ebullient', 'affection'], tags=[897]),
#  TaggedDocument(words=['somehow', 'snagged', 'oscar', 'nomination'], tags=[898]),
#  TaggedDocument(words=['manages', 'show', 'gentle', 'humane', 'side', 'middle', 'eastern', 'world', 'politics'], tags=[899]),
#  TaggedDocument(words=['`', 'realistic', "'"], tags=[900]),
#  TaggedDocument(words=['nicely', 'done'], tags=[901]),
#  TaggedDocument(words=['summer', 'good', 'stuff'], tags=[902]),
#  TaggedDocument(words=['satire', 'easy', 'genuinely', 'satisfying', '.'], tags=[903]),
#  TaggedDocument(words=['sustains'], tags=[904]),
#  TaggedDocument(words=['neither', 'smart'], tags=[905]),
#  TaggedDocument(words=['fare', ',', 'enough', 'creative', 'energy', 'wit', 'entertain', 'ages'], tags=[906]),
#  TaggedDocument(words=['movie', 'powerful', 'provocative', '.'], tags=[907]),
#  TaggedDocument(words=['time', 'literally', 'stops', 'dime', 'tries-so-hard-to-be-cool', '``', 'clockstoppers', ',', '``', "n't", 'mean', 'still', 'wo', "n't", 'feel', 'like', 'longest', '90', 'minutes', 'movie-going', 'life'], tags=[908]),
#  TaggedDocument(words=['sharp', 'edges', 'deep', 'vein', 'sadness'], tags=[909]),
#  TaggedDocument(words=["n't", 'entirely', '`', 'get', "'", 'godard', "'s", 'distinctive', 'discourse', 'still', 'come', 'away', 'sense', 'reserved', 'existential', 'poignancy', '.'], tags=[910]),
#  TaggedDocument(words=['film', "'s", 'sopranos', 'gags', 'incredibly', 'dated', 'unfunny', ',', 'also', 'demonstrate', 'desperate', 'makers', '`', "'re", '-', 'doing-it-for', '-', 'the-cash', "'", 'sequel', '.'], tags=[911]),
#  TaggedDocument(words=["'", 'n', 'safe', 'often', 'play', 'like', 'milquetoast', 'movie', 'week', 'blown', 'big', 'screen'], tags=[912]),
#  TaggedDocument(words=['like', 'skip', 'film', 'buffs', 'get', 'know'], tags=[913]),
#  TaggedDocument(words=['narrative', 'discipline'], tags=[914]),
#  TaggedDocument(words=['samuel', 'l.', 'jackson'], tags=[915]),
#  TaggedDocument(words=['films', 'reason', '.'], tags=[916]),
#  TaggedDocument(words=['old', 'saying', 'goes', ',', "'s", 'true'], tags=[917]),
#  TaggedDocument(words=['take', '12-year-old', 'boy', 'see', 'picture'], tags=[918]),
#  TaggedDocument(words=['aims', 'poetry', 'ends', 'sounding', 'like', 'satire'], tags=[919]),
#  TaggedDocument(words=['come', 'close', 'level', 'intelligence', 'visual', 'splendor', 'seen', 'films'], tags=[920]),
#  TaggedDocument(words=['embracing', 'monty'], tags=[921]),
#  TaggedDocument(words=['hokey'], tags=[922]),
#  TaggedDocument(words=['assaults', 'america', "'s", 'knee-jerk', 'moral', 'sanctimony'], tags=[923]),
#  TaggedDocument(words=["'s", 'hardly', 'fun', 'watch'], tags=[924]),
#  TaggedDocument(words=['get', 'caught', 'thrill', 'company', "'s", 'astonishing', 'growth'], tags=[925]),
#  TaggedDocument(words=["'s", 'par', 'first', 'one'], tags=[926]),
#  TaggedDocument(words=['moody', ',', 'oozing', ',', 'chilling', 'heart-warming'], tags=[927]),
#  TaggedDocument(words=['accuracy', 'observation', 'work', 'director', ',', 'frank', 'novak', ',', 'keeps', 'film', 'grounded', 'undeniable', 'social', 'realism'], tags=[928]),
#  TaggedDocument(words=['right', 'place', ',', 'plea', 'democracy', 'civic', 'action', 'laudable'], tags=[929]),
#  TaggedDocument(words=['ilk'], tags=[930]),
#  TaggedDocument(words=['spy', 'kids', '2', ':', 'island', 'lost', 'dreams', ',', 'however', ',', 'robert', 'rodriguez', 'adorns', 'family-film', 'plot', 'elegance', 'maturity', 'even', 'contemporary', 'adult', 'movies', 'lacking', '.'], tags=[931]),
#  TaggedDocument(words=['kevin', 'kline', 'unfortunately', 'works', 'two', 'star', 'script'], tags=[932]),
#  TaggedDocument(words=['change', 'watching', 'character', ',', 'especially', 'rendered', 'flat'], tags=[933]),
#  TaggedDocument(words=["n't", 'think', '.'], tags=[934]),
#  TaggedDocument(words=['devotees', 'star', 'trek', 'ii', ':', 'wrath', 'khan', 'feel', 'nagging', 'sense', 'deja', 'vu', ',', 'grandeur', 'best', 'next', 'generation', 'episodes', 'lacking'], tags=[935]),
#  TaggedDocument(words=['always', 'joy', 'watch', ',', 'even', 'material', 'first-rate'], tags=[936]),
#  TaggedDocument(words=['great', 'see', 'turd', 'squashed', 'truck', ',', 'preferably', 'semi'], tags=[937]),
#  TaggedDocument(words=['bile', ',', 'irony'], tags=[938]),
#  TaggedDocument(words=['faulty', 'premise', ','], tags=[939]),
#  TaggedDocument(words=['haphazardness'], tags=[940]),
#  TaggedDocument(words=['plot', 'grows', 'thin', 'soon', ','], tags=[941]),
#  TaggedDocument(words=['beloved-major'], tags=[942]),
#  TaggedDocument(words=['means', 'great', 'movie', ',', 'refreshingly', 'forthright', 'one', '.'], tags=[943]),
#  TaggedDocument(words=['crossing-over', 'mumbo', 'jumbo'], tags=[944]),
#  TaggedDocument(words=['virtually', 'unwatchable'], tags=[945]),
#  TaggedDocument(words=['premise', 'smart', ','], tags=[946]),
#  TaggedDocument(words=['amused', 'entertained', 'unfolding', 'bielinsky', "'s", 'cleverly', 'constructed', 'scenario', ',', 'greatly', 'impressed', 'skill', 'actors', 'involved', 'enterprise', '.'], tags=[947]),
#  TaggedDocument(words=['seem', 'bound', 'determined', 'duplicate', 'bela', 'lugosi', "'s", 'now-cliched', 'vampire', 'accent'], tags=[948]),
#  TaggedDocument(words=['light-hearted'], tags=[949]),
#  TaggedDocument(words=['heavy', 'flabby', 'rolls', 'typical', 'toback', 'machinations', '.'], tags=[950]),
#  TaggedDocument(words=['show', 'us', 'good', 'time'], tags=[951]),
#  TaggedDocument(words=['pitiful', ',', 'slapdash', 'disaster', '.'], tags=[952]),
#  TaggedDocument(words=['one', 'year', "'s", 'best'], tags=[953]),
#  TaggedDocument(words=['even', 'witty'], tags=[954]),
#  TaggedDocument(words=['fierce', 'dance'], tags=[955]),
#  TaggedDocument(words=['crippled'], tags=[956]),
#  TaggedDocument(words=['piece', 'crap'], tags=[957]),
#  TaggedDocument(words=['...', 'lady', 'duke', 'surprisingly', 'manages', 'never', 'grow', 'boring', '...', 'proves', 'rohmer', 'still', 'sense', 'audience', '.'], tags=[958]),
#  TaggedDocument(words=['wondrous', 'love', 'story', 'years', ',', 'great', 'film', '.'], tags=[959]),
#  TaggedDocument(words=['story', 'young', 'chinese', 'woman', ',', 'ah', 'na', ',', 'come', 'new', 'york', 'city', 'replace', 'past', 'tragedy', 'american', 'dream'], tags=[960]),
#  TaggedDocument(words=['particularly', 'impressive'], tags=[961]),
#  TaggedDocument(words=['process', 'comes', 'looking', 'like', 'something', 'wholly', 'original'], tags=[962]),
#  TaggedDocument(words=['submerging'], tags=[963]),
#  TaggedDocument(words=['nearly', 'fresh', 'enjoyable'], tags=[964]),
#  TaggedDocument(words=['miserable', 'smug'], tags=[965]),
#  TaggedDocument(words=['great', 'pleasure'], tags=[966]),
#  TaggedDocument(words=['unfolds', 'predictably', ',', 'adventures', 'happen', 'along', 'way', 'seem', 'repetitive', 'designed', 'fill', 'time', ',', 'providing', 'real', 'sense', 'suspense', '.'], tags=[967]),
#  TaggedDocument(words=['fascinating', ',', 'dark', 'thriller'], tags=[968]),
#  TaggedDocument(words=['taiwanese', 'auteur', 'tsai', 'ming-liang', ',', 'good', 'news', 'anyone', "'s", 'fallen', 'sweet', ',', 'melancholy', 'spell', 'unique', 'director', "'s", 'previous', 'films', '.'], tags=[969]),
#  TaggedDocument(words=['reality', 'drain'], tags=[970]),
#  TaggedDocument(words=['way', 'tolerate', 'insipid', ',', 'brutally', 'clueless', 'film', 'might', 'large', 'dose', 'painkillers', '.'], tags=[971]),
#  TaggedDocument(words=['historic', 'scandal'], tags=[972]),
#  TaggedDocument(words=["'s", 'steeped', 'mystery', 'ravishing', ',', 'baroque', 'beauty'], tags=[973]),
#  TaggedDocument(words=['cool', 'stuff', 'packed', 'espn', "'s", 'ultimate', 'x', '.'], tags=[974]),
#  TaggedDocument(words=['idea', '(', 'middle-aged', 'romance', ')', 'handled', 'well', ',', 'except', 'fine', 'star', 'performances'], tags=[975]),
#  TaggedDocument(words=['lamentations', 'pretty', 'much', 'self-centered'], tags=[976]),
#  TaggedDocument(words=['pretty', 'decent', 'kid-pleasing', ','], tags=[977]),
#  TaggedDocument(words=['classic', 'romantic', 'comedy', 'aspires'], tags=[978]),
#  TaggedDocument(words=[',', 'bigelow', 'demonstrates', 'breadth', 'vision', 'attention', 'detail', 'propels', 'upper', 'echelons', 'directing', 'world', '.'], tags=[979]),
#  TaggedDocument(words=['refreshingly', 'unhibited', 'enthusiasm', 'people', ',', 'spite', 'clearly', 'evident', 'poverty', 'hardship', ',', 'bring', 'music'], tags=[980]),
#  TaggedDocument(words=['would', "n't", 'taken', 'protagonists', 'full', 'hour', 'determine', 'order', 'kill', 'zombie', 'must', 'shoot', 'head'], tags=[981]),
#  TaggedDocument(words=['give', 'pretty', 'good', 'overall', 'picture', 'situation', 'laramie', 'following', 'murder', 'matthew', 'shepard'], tags=[982]),
#  TaggedDocument(words=['fine', 'line', 'cheese', 'earnestness', 'remarkably', 'well'], tags=[983]),
#  TaggedDocument(words=['documentary', 'fails', 'live', '--', 'offer', 'new', 'insight', '--', 'chosen', 'topic'], tags=[984]),
#  TaggedDocument(words=['serious', 'movie-goers', 'embarking', 'upon', 'journey'], tags=[985]),
#  TaggedDocument(words=['insistent', 'repetitive'], tags=[986]),
#  TaggedDocument(words=['nausea'], tags=[987]),
#  TaggedDocument(words=['survival', 'wrapped', 'heart-pounding', 'suspense', 'stylish', 'psychological', 'thriller'], tags=[988]),
#  TaggedDocument(words=['art'], tags=[989]),
#  TaggedDocument(words=['seems', 'exist', 'climactic', 'setpiece'], tags=[990]),
#  TaggedDocument(words=['silly', 'scary'], tags=[991]),
#  TaggedDocument(words=["'s", 'funny', '.'], tags=[992]),
#  TaggedDocument(words=['execution', 'skill'], tags=[993]),
#  TaggedDocument(words=["'s", 'coherent', ',', 'well', 'shot', ',', 'tartly'], tags=[994]),
#  TaggedDocument(words=['wish', 'home', 'watching', 'movie', 'instead', 'theater', 'watching', 'one'], tags=[995]),
#  TaggedDocument(words=["'s", 'point', 'extracting', 'bare', 'bones', 'byatt', "'s", 'plot', 'purposes', 'bland', 'hollywood', 'romance'], tags=[996]),
#  TaggedDocument(words=['underdeveloped'], tags=[997]),
#  TaggedDocument(words=['jokes', 'flat'], tags=[998]),
#  TaggedDocument(words=['heartening', 'tale', 'small', 'victories'], tags=[999]),
#  ...]

# %%
vector_size = 100

model_doc2vec = Doc2Vec(tagged_train_sent+tagged_test_sent, vector_size = vector_size, window = 4, min_count = 1, epochs = 100)

# %%
x_train = train_data.loc[:,'sentence']
y_train = train_data.loc[:,'label']
x_test = test_data.loc[:,'sentence']
y_test = test_data.loc[:,'label']

# %%
import tqdm

x_train_preprocessed = [model_doc2vec.infer_vector(word_tokenize(sent.lower())) for sent in tqdm.tqdm(x_train)]
x_test_preprocessed = [model_doc2vec.infer_vector(word_tokenize(sent.lower())) for sent in tqdm.tqdm(x_test)]
# Out:
# 100%|██████████| 67349/67349 [03:49<00:00, 293.27it/s]
# 100%|██████████| 872/872 [00:03<00:00, 248.69it/s]

# %%
import numpy as np

print(np.array(x_train_preprocessed).shape)
# Out:
# (67349, 100)

# %%
import numpy as np
import pandas as pd


df_train = pd.DataFrame(np.array(x_train_preprocessed).reshape([x_train.shape[0],vector_size]))
df_test = pd.DataFrame(np.array(x_test_preprocessed).reshape([x_test.shape[0],vector_size]))

df_train.to_csv('df_train_doc2vec_256_2.csv')
df_test.to_csv('df_test_doc2vec_256_2.csv')
# Out:
# C:\Users\kolma\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
import pandas as pd

# x_train_preprocessed = pd.read_csv('df_train_doc2vec_100_2.csv')
# x_test_preprocessed = pd.read_csv('df_test_doc2vec_100_2.csv')
# x_train_preprocessed = x_train_preprocessed.drop('Unnamed: 0', axis=1)
# x_test_preprocessed = x_test_preprocessed.drop('Unnamed: 0', axis=1)

# %%
len(x_train_preprocessed)
# Out:
# 67349

# %%
from lazypredict.Supervised import LazyClassifier
import numpy as np
import pandas as pd

x_valid_preprocessed = x_train_preprocessed[63000:len(x_train_preprocessed)]
x_train_preprocessed = x_train_preprocessed[0:63000]

y_valid = y_train[63000:len(y_train)]
y_train = y_train[0:63000]

print(len(x_valid_preprocessed))
print(len(x_train_preprocessed))
print(len(y_valid))
print(len(y_train))
# Out:
# 4349
# 63000
# 4349
# 63000

# %% [markdown]
# ## Basic classifiers

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)

vector_size=100

models,predictions = clf.fit(np.array(x_train_preprocessed).reshape([len(x_train_preprocessed),vector_size]), 
                             np.array(x_valid_preprocessed).reshape([len(x_valid_preprocessed),vector_size]), 
                             y_train, y_valid)

print(models)
# Out:
# 100%|██████████| 29/29 [1:28:08<00:00, 182.35s/it]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NuSVC                              0.74               0.72     0.72      0.73
# KNeighborsClassifier               0.70               0.69     0.69      0.70
# SVC                                0.72               0.69     0.69      0.70
# ExtraTreesClassifier               0.69               0.66     0.66      0.67
# RandomForestClassifier             0.68               0.66     0.66      0.67
# XGBClassifier                      0.67               0.66     0.66      0.66
# LGBMClassifier                     0.66               0.64     0.64      0.64
# QuadraticDiscriminantAnalysis      0.64               0.61     0.61      0.62
# CalibratedClassifierCV             0.63               0.61     0.61      0.61
# LinearSVC                          0.63               0.61     0.61      0.61
# LogisticRegression                 0.63               0.61     0.61      0.61
# LinearDiscriminantAnalysis         0.63               0.61     0.61      0.61
# RidgeClassifier                    0.63               0.61     0.61      0.61
# RidgeClassifierCV                  0.63               0.61     0.61      0.61
# BaggingClassifier                  0.61               0.61     0.61      0.61
# SGDClassifier                      0.63               0.60     0.60      0.61
# NearestCentroid                    0.60               0.59     0.59      0.60
# AdaBoostClassifier                 0.61               0.59     0.59      0.60
# BernoulliNB                        0.58               0.57     0.57      0.58
# Perceptron                         0.57               0.56     0.56      0.57
# DecisionTreeClassifier             0.57               0.56     0.56      0.57
# ExtraTreeClassifier                0.56               0.56     0.56      0.57
# GaussianNB                         0.57               0.55     0.55      0.56
# PassiveAggressiveClassifier        0.53               0.53     0.53      0.53
# DummyClassifier                    0.50               0.50     0.50      0.50
#
#                                Time Taken
# Model
# NuSVC                             3756.08
# KNeighborsClassifier                93.95
# SVC                               1020.78
# ExtraTreesClassifier                24.97
# RandomForestClassifier              67.85
# XGBClassifier                       40.63
# LGBMClassifier                       4.74
# QuadraticDiscriminantAnalysis        1.33
# CalibratedClassifierCV             110.61
# LinearSVC                           32.56
# LogisticRegression                   0.96
# LinearDiscriminantAnalysis           2.09
# RidgeClassifier                      0.43
# RidgeClassifierCV                    1.67
# BaggingClassifier                   68.12
# SGDClassifier                        1.80
# NearestCentroid                      0.40
# AdaBoostClassifier                  41.84
# BernoulliNB                          0.43
# Perceptron                           0.60
# DecisionTreeClassifier              10.85
# ExtraTreeClassifier                  0.48
# GaussianNB                           0.58
# PassiveAggressiveClassifier          0.50
# DummyClassifier                      0.26

# %%
models = clf.provide_models(np.array(x_train_preprocessed).reshape([len(x_train_preprocessed),vector_size]), np.array(x_valid_preprocessed).reshape([len(x_valid_preprocessed),vector_size]), y_train, y_valid)
predictions = models['NuSVC'].predict(np.array(x_test_preprocessed).reshape([x_test.shape[0],vector_size]))

print(sum([predictions[i] == y_test[i] for i in range(len(x_test))]), len(x_test))
# Out:
# 512 872

# %%
from sklearn.metrics import log_loss, f1_score, roc_curve, auc
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

def eval(y_true, y_pred):
    print('Classification Report:')
    print(classification_report(y_true, y_pred, labels=[1,0], digits=4))

    cm = confusion_matrix(y_true, y_pred, labels=[1,0])
    ax= plt.subplot()
    sns.heatmap(cm, annot=True, ax = ax, cmap='Blues', fmt="d")

    ax.set_title('Confusion Matrix')

    ax.set_xlabel('Predicted Labels')
    ax.set_ylabel('True Labels')

    ax.xaxis.set_ticklabels(['FAKE', 'REAL'])
    ax.yaxis.set_ticklabels(['FAKE', 'REAL'])
# model evaluation

print("BERT, best general classifier, no balancing techniques")
print("F-measure or f1-score: ", f1_score(y_test, predictions))
print("Log loss: ", log_loss(y_test, predictions))

fpr, tpr, thresholds = roc_curve(y_test, predictions)

print("AUC: ", auc(fpr, tpr))

eval(y_test, predictions)
# Out:
# BERT, best general classifier, no balancing techniques
# F-measure or f1-score:  0.7019867549668874
# Log loss:  14.259439639098753
# AUC:  0.5802812157952345
# Classification Report:
#               precision    recall  f1-score   support
#
#            1     0.5550    0.9550    0.7020       444
#            0     0.8148    0.2056    0.3284       428
#
#     accuracy                         0.5872       872
#    macro avg     0.6849    0.5803    0.5152       872
# weighted avg     0.6825    0.5872    0.5186       872

# %% [markdown]
# ## LSTM architecture 1

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Embedding
from keras.callbacks import EarlyStopping, ModelCheckpoint
from matplotlib import pyplot
from keras.layers import Bidirectional

# %%
lstm = Sequential()
lstm.add(Bidirectional(LSTM(100, return_sequences=False)))
lstm.add(Dense(1, activation='sigmoid'))

callback = EarlyStopping(monitor='val_loss', patience=7)

lstm.compile(loss='binary_crossentropy', optimizer='adam')
lstm.fit(np.array(x_train_preprocessed).reshape([len(x_train_preprocessed),1,vector_size]), y_train, validation_data=(np.array(x_valid_preprocessed).reshape([len(x_valid_preprocessed),1,vector_size]), y_valid), epochs=50, batch_size=128, verbose=1, shuffle=True, callbacks=[callback])
# Out:
# Epoch 1/50
# 493/493 [==============================] - 6s 6ms/step - loss: 0.6474 - val_loss: 0.6417
# Epoch 2/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.6350 - val_loss: 0.6381
# Epoch 3/50
# 493/493 [==============================] - 3s 5ms/step - loss: 0.6324 - val_loss: 0.6369
# Epoch 4/50
# 493/493 [==============================] - 3s 5ms/step - loss: 0.6297 - val_loss: 0.6351
# Epoch 5/50
# 493/493 [==============================] - 3s 5ms/step - loss: 0.6268 - val_loss: 0.6345
# Epoch 6/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.6231 - val_loss: 0.6338
# Epoch 7/50
# 493/493 [==============================] - 4s 7ms/step - loss: 0.6196 - val_loss: 0.6304
# Epoch 8/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.6149 - val_loss: 0.6321
# Epoch 9/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.6098 - val_loss: 0.6280
# Epoch 10/50
# 493/493 [==============================] - 3s 5ms/step - loss: 0.6045 - val_loss: 0.6246
# Epoch 11/50
# 493/493 [==============================] - 3s 5ms/step - loss: 0.6001 - val_loss: 0.6280
# Epoch 12/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.5946 - val_loss: 0.6213
# Epoch 13/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.5898 - val_loss: 0.6242
# Epoch 14/50
# 493/493 [==============================] - 3s 5ms/step - loss: 0.5848 - val_loss: 0.6233
# Epoch 15/50
# 493/493 [==============================] - 3s 5ms/step - loss: 0.5799 - val_loss: 0.6188
# Epoch 16/50
# 493/493 [==============================] - 3s 5ms/step - loss: 0.5766 - val_loss: 0.6213
# Epoch 17/50
# 493/493 [==============================] - 3s 7ms/step - loss: 0.5708 - val_loss: 0.6177
# Epoch 18/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.5669 - val_loss: 0.6197
# Epoch 19/50
# 493/493 [==============================] - 4s 7ms/step - loss: 0.5631 - val_loss: 0.6232
# Epoch 20/50
#  - ETA: 2s - loss: 0.5609
# Epoch 21/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.5550 - val_loss: 0.6163
# Epoch 22/50
# 493/493 [==============================] - 3s 5ms/step - loss: 0.5517 - val_loss: 0.6187
# Epoch 23/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.5481 - val_loss: 0.6166
# Epoch 24/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.5448 - val_loss: 0.6179
# Epoch 25/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5411 - val_loss: 0.6173
# Epoch 26/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5385 - val_loss: 0.6167
# Epoch 27/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5342 - val_loss: 0.6204

# %%
import math

predictions_lstm = lstm.predict(np.array(x_test_preprocessed).reshape([len(x_test_preprocessed),1,vector_size]))

print(sum([math.ceil(predictions_lstm[i]) == y_test[i] for i in range(len(x_test))]), len(x_test))
# Out:
# 444 872

# %%
# model evaluation

print("Doc2Vec, LSTM, no balancing techniques")
print("F-measure or f1-score: ", f1_score(y_test, [math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))]))
print("Log loss: ", log_loss(y_test, predictions_lstm))
print("Log loss: ", log_loss(y_test, [math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))]))

fpr, tpr, thresholds = roc_curve(y_test, predictions_lstm)

print("AUC: ", auc(fpr, tpr))

fpr, tpr, thresholds = roc_curve(y_test,[math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))])

print("AUC: ", auc(fpr, tpr))

eval(y_test, [math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))])
# Out:
# Doc2Vec, LSTM, no balancing techniques
# F-measure or f1-score:  0.6747720364741641
# Log loss:  nan
# Log loss:  16.95291115220401
# AUC:  0.7558121790014314
# AUC:  0.5
# Classification Report:
#               precision    recall  f1-score   support
#
#            1     0.5092    1.0000    0.6748       444
#            0     0.0000    0.0000    0.0000       428
#
#     accuracy                         0.5092       872
#    macro avg     0.2546    0.5000    0.3374       872
# weighted avg     0.2593    0.5092    0.3436       872

# %% [markdown]
# ## LSTM architecture 2

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Embedding
from keras.callbacks import EarlyStopping, ModelCheckpoint
from matplotlib import pyplot
from keras.layers import Bidirectional

# %%
embedding_vecor_length = 100
max_review_length=500
top_words=7500

lstm = Sequential()
# lstm.add(Embedding(top_words, embedding_vecor_length, input_length=max_review_length))
lstm.add(LSTM(100))
lstm.add(Dense(1, activation='sigmoid'))

callback = EarlyStopping(monitor='val_loss', patience=7)

lstm.compile(loss='binary_crossentropy', optimizer='adam')
lstm.fit(np.array(x_train_preprocessed).reshape([len(x_train_preprocessed),1,vector_size]), y_train, validation_data=(np.array(x_valid_preprocessed).reshape([len(x_valid_preprocessed),1,vector_size]), y_valid), epochs=50, batch_size=128, verbose=1, shuffle=True, callbacks=[callback])
# Out:
# Epoch 1/50
# 493/493 [==============================] - 5s 6ms/step - loss: 0.6510 - val_loss: 0.6406
# Epoch 2/50
# 493/493 [==============================] - 2s 4ms/step - loss: 0.6353 - val_loss: 0.6378
# Epoch 3/50
# 493/493 [==============================] - 2s 5ms/step - loss: 0.6327 - val_loss: 0.6379
# Epoch 4/50
# 493/493 [==============================] - 2s 4ms/step - loss: 0.6306 - val_loss: 0.6375
# Epoch 5/50
# 493/493 [==============================] - 2s 4ms/step - loss: 0.6277 - val_loss: 0.6351
# Epoch 6/50
# 493/493 [==============================] - 2s 5ms/step - loss: 0.6253 - val_loss: 0.6341
# Epoch 7/50
# 493/493 [==============================] - 2s 4ms/step - loss: 0.6219 - val_loss: 0.6329
# Epoch 8/50
# 493/493 [==============================] - 2s 5ms/step - loss: 0.6182 - val_loss: 0.6308
# Epoch 9/50
# 493/493 [==============================] - 2s 5ms/step - loss: 0.6149 - val_loss: 0.6282
# Epoch 10/50
# 493/493 [==============================] - 2s 4ms/step - loss: 0.6106 - val_loss: 0.6273
# Epoch 11/50
# 493/493 [==============================] - 3s 5ms/step - loss: 0.6067 - val_loss: 0.6266
# Epoch 12/50
# 493/493 [==============================] - 2s 5ms/step - loss: 0.6023 - val_loss: 0.6254
# Epoch 13/50
# 493/493 [==============================] - 3s 5ms/step - loss: 0.5981 - val_loss: 0.6225
# Epoch 14/50
# 493/493 [==============================] - 2s 5ms/step - loss: 0.5949 - val_loss: 0.6209
# Epoch 15/50
# 493/493 [==============================] - 3s 5ms/step - loss: 0.5900 - val_loss: 0.6227
# Epoch 16/50
# 493/493 [==============================] - 2s 4ms/step - loss: 0.5856 - val_loss: 0.6240
# Epoch 17/50
# 493/493 [==============================] - 2s 4ms/step - loss: 0.5823 - val_loss: 0.6201
# Epoch 18/50
# 493/493 [==============================] - 3s 5ms/step - loss: 0.5781 - val_loss: 0.6176
# Epoch 19/50
# 493/493 [==============================] - 2s 5ms/step - loss: 0.5743 - val_loss: 0.6301
# Epoch 20/50
# 493/493 [==============================] - 3s 5ms/step - loss: 0.5715 - val_loss: 0.6160
# Epoch 21/50
# 493/493 [==============================] - 2s 4ms/step - loss: 0.5679 - val_loss: 0.6151
# Epoch 22/50
# 493/493 [==============================] - 2s 5ms/step - loss: 0.5646 - val_loss: 0.6157
# Epoch 23/50
# 493/493 [==============================] - 2s 4ms/step - loss: 0.5617 - val_loss: 0.6152
# Epoch 24/50
# 493/493 [==============================] - 2s 5ms/step - loss: 0.5579 - val_loss: 0.6160
# Epoch 25/50
# 493/493 [==============================] - 2s 5ms/step - loss: 0.5549 - val_loss: 0.6151
# Epoch 26/50
# 493/493 [==============================] - 2s 4ms/step - loss: 0.5518 - val_loss: 0.6174
# Epoch 27/50
# 493/493 [==============================] - 3s 5ms/step - loss: 0.5493 - val_loss: 0.6166
# Epoch 28/50
# 493/493 [==============================] - 2s 5ms/step - loss: 0.5459 - val_loss: 0.6168

# %%
import math

predictions_lstm = lstm.predict(np.array(x_test_preprocessed).reshape([len(x_test_preprocessed),1,vector_size]))

print(sum([math.ceil(predictions_lstm[i]) == y_test[i] for i in range(len(x_test))]), len(x_test))
# Out:
# 444 872

# %%
# model evaluation

print("Doc2Vec, LSTM, no balancing techniques")
print("F-measure or f1-score: ", f1_score(y_test, [math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))]))
print("Log loss: ", log_loss(y_test, predictions_lstm))
print("Log loss: ", log_loss(y_test, [math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))]))

fpr, tpr, thresholds = roc_curve(y_test, predictions_lstm)

print("AUC: ", auc(fpr, tpr))

fpr, tpr, thresholds = roc_curve(y_test,[math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))])

print("AUC: ", auc(fpr, tpr))

eval(y_test, [math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))])
# Out:
# Doc2Vec, LSTM, no balancing techniques
# F-measure or f1-score:  0.6747720364741641
# Log loss:  nan
# Log loss:  16.95291115220401
# AUC:  0.7646975246274312
# AUC:  0.5
# Classification Report:
#               precision    recall  f1-score   support
#
#            1     0.5092    1.0000    0.6748       444
#            0     0.0000    0.0000    0.0000       428
#
#     accuracy                         0.5092       872
#    macro avg     0.2546    0.5000    0.3374       872
# weighted avg     0.2593    0.5092    0.3436       872

# %% [markdown]
# ## LSTM architecture 3

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
from matplotlib import pyplot
from keras.layers import Bidirectional

# %%
lstm = Sequential()
lstm.add(Bidirectional(LSTM(100, return_sequences=False)))
lstm.add(Dropout(0.2))
lstm.add(Dense(1, activation='sigmoid'))

callback = EarlyStopping(monitor='val_loss', patience=7)

lstm.compile(loss='binary_crossentropy', optimizer='adam')
lstm.fit(np.array(x_train_preprocessed).reshape([len(x_train_preprocessed),1,vector_size]), y_train, validation_data=(np.array(x_valid_preprocessed).reshape([len(x_valid_preprocessed),1,vector_size]), y_valid), epochs=50, batch_size=128, verbose=1, shuffle=True, callbacks=[callback])
# Out:
# Epoch 1/50
# 493/493 [==============================] - 7s 9ms/step - loss: 0.6502 - val_loss: 0.6397
# Epoch 2/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.6353 - val_loss: 0.6391
# Epoch 3/50
#  - ETA: 0s - loss: 0.6339
# Epoch 4/50
# 493/493 [==============================] - 3s 7ms/step - loss: 0.6310 - val_loss: 0.6367
# Epoch 5/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.6286 - val_loss: 0.6354
# Epoch 6/50
#  - ETA: 2s - loss: 0.6267
# Epoch 7/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.6230 - val_loss: 0.6326
# Epoch 8/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.6198 - val_loss: 0.6318
# Epoch 9/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.6159 - val_loss: 0.6292
# Epoch 10/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.6125 - val_loss: 0.6282
# Epoch 11/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.6085 - val_loss: 0.6272
# Epoch 12/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.6047 - val_loss: 0.6241
# Epoch 13/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.6006 - val_loss: 0.6235
# Epoch 14/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.5968 - val_loss: 0.6217
# Epoch 15/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.5937 - val_loss: 0.6222
# Epoch 16/50
# 493/493 [==============================] - 3s 7ms/step - loss: 0.5894 - val_loss: 0.6228
# Epoch 17/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.5862 - val_loss: 0.6243
# Epoch 18/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.5835 - val_loss: 0.6180
# Epoch 19/50
# 493/493 [==============================] - 3s 7ms/step - loss: 0.5796 - val_loss: 0.6178
# Epoch 20/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.5764 - val_loss: 0.6180
# Epoch 21/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.5740 - val_loss: 0.6204
# Epoch 22/50
# 493/493 [==============================] - 3s 7ms/step - loss: 0.5705 - val_loss: 0.6265
# Epoch 23/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.5678 - val_loss: 0.6161
# Epoch 24/50
# 493/493 [==============================] - 3s 7ms/step - loss: 0.5649 - val_loss: 0.6193
# Epoch 25/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.5621 - val_loss: 0.6176
# Epoch 26/50
# 493/493 [==============================] - 3s 7ms/step - loss: 0.5600 - val_loss: 0.6199
# Epoch 27/50
# 493/493 [==============================] - 3s 7ms/step - loss: 0.5568 - val_loss: 0.6179
# Epoch 28/50
# 493/493 [==============================] - 3s 7ms/step - loss: 0.5547 - val_loss: 0.6173
# Epoch 29/50
# 493/493 [==============================] - 3s 6ms/step - loss: 0.5516 - val_loss: 0.6170
# Epoch 30/50
# 493/493 [==============================] - 3s 7ms/step - loss: 0.5489 - val_loss: 0.6185

# %%
import math

predictions_lstm = lstm.predict(np.array(x_test_preprocessed).reshape([len(x_test_preprocessed),1,vector_size]))

print(sum([math.ceil(predictions_lstm[i]) == y_test[i] for i in range(len(x_test))]), len(x_test))
# Out:
# 444 872

# %%
# model evaluation

print("Doc2Vec, LSTM, no balancing techniques")
print("F-measure or f1-score: ", f1_score(y_test, [math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))]))
print("Log loss: ", log_loss(y_test, predictions_lstm))
print("Log loss: ", log_loss(y_test, [math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))]))

fpr, tpr, thresholds = roc_curve(y_test, predictions_lstm)

print("AUC: ", auc(fpr, tpr))

fpr, tpr, thresholds = roc_curve(y_test,[math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))])

print("AUC: ", auc(fpr, tpr))

eval(y_test, [math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))])
# Out:
# Doc2Vec, LSTM, no balancing techniques
# F-measure or f1-score:  0.6747720364741641
# Log loss:  nan
# Log loss:  16.95291115220401
# AUC:  0.759340532120906
# AUC:  0.5
# Classification Report:
#               precision    recall  f1-score   support
#
#            1     0.5092    1.0000    0.6748       444
#            0     0.0000    0.0000    0.0000       428
#
#     accuracy                         0.5092       872
#    macro avg     0.2546    0.5000    0.3374       872
# weighted avg     0.2593    0.5092    0.3436       872

# %% [markdown]
# ## LSTM architecture 4

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
from matplotlib import pyplot
from keras.layers import Bidirectional

# %%
lstm = Sequential()
lstm.add(Bidirectional(LSTM(100, dropout=0.2, recurrent_dropout=0.2)))
lstm.add(Dropout(0.2))
lstm.add(Dense(1, activation='sigmoid'))

callback = EarlyStopping(monitor='val_loss', patience=7)

lstm.compile(loss='binary_crossentropy', optimizer='adam')
lstm.fit(np.array(x_train_preprocessed).reshape([len(x_train_preprocessed),1,vector_size]), y_train, validation_data=(np.array(x_valid_preprocessed).reshape([len(x_valid_preprocessed),1,vector_size]), y_valid), epochs=50, batch_size=128, verbose=1, shuffle=True, callbacks=[callback])
# Out:
# Epoch 1/50
# 493/493 [==============================] - 12s 11ms/step - loss: 0.6567 - val_loss: 0.6447
# Epoch 2/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.6460 - val_loss: 0.6411
# Epoch 3/50
# 493/493 [==============================] - 5s 10ms/step - loss: 0.6442 - val_loss: 0.6389
# Epoch 4/50
#  - ETA: 1s - loss: 0.6428
# Epoch 5/50
# 493/493 [==============================] - 5s 10ms/step - loss: 0.6391 - val_loss: 0.6364
# Epoch 6/50
# 493/493 [==============================] - 5s 10ms/step - loss: 0.6371 - val_loss: 0.6371
# Epoch 7/50
# 493/493 [==============================] - 5s 10ms/step - loss: 0.6349 - val_loss: 0.6353
# Epoch 8/50
# 493/493 [==============================] - 5s 10ms/step - loss: 0.6323 - val_loss: 0.6362
# Epoch 9/50
# 493/493 [==============================] - 5s 10ms/step - loss: 0.6303 - val_loss: 0.6343
# Epoch 10/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.6271 - val_loss: 0.6351
# Epoch 11/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.6239 - val_loss: 0.6313
# Epoch 12/50
# 493/493 [==============================] - 5s 10ms/step - loss: 0.6219 - val_loss: 0.6285
# Epoch 13/50
# 493/493 [==============================] - 5s 9ms/step - loss: 0.6180 - val_loss: 0.6262
# Epoch 14/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.6164 - val_loss: 0.6253
# Epoch 15/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.6134 - val_loss: 0.6252
# Epoch 16/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.6108 - val_loss: 0.6236
# Epoch 17/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.6075 - val_loss: 0.6224
# Epoch 18/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.6059 - val_loss: 0.6233
# Epoch 19/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.6031 - val_loss: 0.6196
# Epoch 20/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.6010 - val_loss: 0.6232
# Epoch 21/50
# 493/493 [==============================] - 5s 9ms/step - loss: 0.5994 - val_loss: 0.6185
# Epoch 22/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5966 - val_loss: 0.6199
# Epoch 23/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5956 - val_loss: 0.6182
# Epoch 24/50
#  - ETA: 1s - loss: 0.5930
# Epoch 25/50
#  - ETA: 3s - loss: 0.5896
# Epoch 26/50
# 493/493 [==============================] - 5s 10ms/step - loss: 0.5895 - val_loss: 0.6196
# Epoch 27/50
# 493/493 [==============================] - 5s 9ms/step - loss: 0.5880 - val_loss: 0.6160
# Epoch 28/50
# 493/493 [==============================] - 5s 10ms/step - loss: 0.5869 - val_loss: 0.6162
# Epoch 29/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5854 - val_loss: 0.6157
# Epoch 30/50
# 493/493 [==============================] - 5s 10ms/step - loss: 0.5829 - val_loss: 0.6166
# Epoch 31/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5818 - val_loss: 0.6144
# Epoch 32/50
#  - ETA: 2s - loss: 0.5775
# Epoch 33/50
# 493/493 [==============================] - 5s 10ms/step - loss: 0.5781 - val_loss: 0.6161
# Epoch 34/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5764 - val_loss: 0.6138
# Epoch 35/50
# 493/493 [==============================] - 5s 9ms/step - loss: 0.5749 - val_loss: 0.6125
# Epoch 36/50
# 493/493 [==============================] - 5s 9ms/step - loss: 0.5746 - val_loss: 0.6157
# Epoch 37/50
# 493/493 [==============================] - 5s 9ms/step - loss: 0.5726 - val_loss: 0.6144
# Epoch 38/50
# 493/493 [==============================] - 5s 10ms/step - loss: 0.5716 - val_loss: 0.6156
# Epoch 39/50
#  - ETA: 5s - loss: 0.5672
# Epoch 40/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5680 - val_loss: 0.6133
# Epoch 41/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5678 - val_loss: 0.6183
# Epoch 42/50
# 493/493 [==============================] - 5s 10ms/step - loss: 0.5669 - val_loss: 0.6170

# %%
import math

predictions_lstm = lstm.predict(np.array(x_test_preprocessed).reshape([len(x_test_preprocessed),1,vector_size]))

print(sum([math.ceil(predictions_lstm[i]) == y_test[i] for i in range(len(x_test))]), len(x_test))
# Out:
# 444 872

# %%
# model evaluation

print("Doc2Vec, LSTM, no balancing techniques")
print("F-measure or f1-score: ", f1_score(y_test, [math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))]))
print("Log loss: ", log_loss(y_test, predictions_lstm))
print("Log loss: ", log_loss(y_test, [math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))]))

fpr, tpr, thresholds = roc_curve(y_test, predictions_lstm)

print("AUC: ", auc(fpr, tpr))

fpr, tpr, thresholds = roc_curve(y_test,[math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))])

print("AUC: ", auc(fpr, tpr))

eval(y_test, [math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))])
# Out:
# Doc2Vec, LSTM, no balancing techniques
# F-measure or f1-score:  0.6747720364741641
# Log loss:  nan
# Log loss:  16.95291115220401
# AUC:  0.7585248800202071
# AUC:  0.5
# Classification Report:
#               precision    recall  f1-score   support
#
#            1     0.5092    1.0000    0.6748       444
#            0     0.0000    0.0000    0.0000       428
#
#     accuracy                         0.5092       872
#    macro avg     0.2546    0.5000    0.3374       872
# weighted avg     0.2593    0.5092    0.3436       872

# %% [markdown]
# ## LSTM architecture 5

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
from matplotlib import pyplot
from keras.layers import Bidirectional

# %%
lstm = Sequential()
lstm.add(Bidirectional(LSTM(100, dropout=0.2, recurrent_dropout=0.2)))
lstm.add(Dense(1, activation='sigmoid'))

callback = EarlyStopping(monitor='val_loss', patience=7)

lstm.compile(loss='binary_crossentropy', optimizer='adam')
lstm.fit(np.array(x_train_preprocessed).reshape([len(x_train_preprocessed),1,vector_size]), y_train, validation_data=(np.array(x_valid_preprocessed).reshape([len(x_valid_preprocessed),1,vector_size]), y_valid), epochs=50, batch_size=128, verbose=1, shuffle=True, callbacks=[callback])
# Out:
# Epoch 1/50
# 493/493 [==============================] - 11s 10ms/step - loss: 0.6571 - val_loss: 0.6426
# Epoch 2/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.6452 - val_loss: 0.6410
# Epoch 3/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.6430 - val_loss: 0.6395
# Epoch 4/50
#  - ETA: 2s - loss: 0.6401
# Epoch 5/50
#  - ETA: 0s - loss: 0.6375
# Epoch 6/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.6352 - val_loss: 0.6358
# Epoch 7/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.6317 - val_loss: 0.6336
# Epoch 8/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.6290 - val_loss: 0.6315
# Epoch 9/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.6261 - val_loss: 0.6314
# Epoch 10/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.6221 - val_loss: 0.6301
# Epoch 11/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.6196 - val_loss: 0.6310
# Epoch 12/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.6155 - val_loss: 0.6253
# Epoch 13/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.6121 - val_loss: 0.6252
# Epoch 14/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.6083 - val_loss: 0.6233
# Epoch 15/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.6057 - val_loss: 0.6231
# Epoch 16/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.6014 - val_loss: 0.6221
# Epoch 17/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5994 - val_loss: 0.6207
# Epoch 18/50
# 493/493 [==============================] - 5s 9ms/step - loss: 0.5955 - val_loss: 0.6184
# Epoch 19/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5921 - val_loss: 0.6220
# Epoch 20/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5901 - val_loss: 0.6182
# Epoch 21/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5875 - val_loss: 0.6174
# Epoch 22/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5857 - val_loss: 0.6148
# Epoch 23/50
#  - ETA: 3s - loss: 0.5805
# Epoch 24/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5810 - val_loss: 0.6170
# Epoch 25/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5789 - val_loss: 0.6145
# Epoch 26/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5766 - val_loss: 0.6183
# Epoch 27/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5755 - val_loss: 0.6154
# Epoch 28/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5727 - val_loss: 0.6179
# Epoch 29/50
#  - ETA: 4s - loss: 0.5659
# Epoch 30/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5685 - val_loss: 0.6157
# Epoch 31/50
#  - ETA: 0s - loss: 0.5675
# Epoch 32/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5659 - val_loss: 0.6134
# Epoch 33/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5636 - val_loss: 0.6142
# Epoch 34/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5630 - val_loss: 0.6129
# Epoch 35/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5601 - val_loss: 0.6114
# Epoch 36/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5594 - val_loss: 0.6147
# Epoch 37/50
#  - ETA: 2s - loss: 0.5561
# Epoch 38/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5551 - val_loss: 0.6103
# Epoch 39/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5541 - val_loss: 0.6121
# Epoch 40/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5533 - val_loss: 0.6123
# Epoch 41/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5507 - val_loss: 0.6254
# Epoch 42/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5501 - val_loss: 0.6132
# Epoch 43/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5496 - val_loss: 0.6166
# Epoch 44/50
# 493/493 [==============================] - 5s 10ms/step - loss: 0.5468 - val_loss: 0.6112

# %%
import math

predictions_lstm = lstm.predict(np.array(x_test_preprocessed).reshape([len(x_test_preprocessed),1,vector_size]))

print(sum([math.ceil(predictions_lstm[i]) == y_test[i] for i in range(len(x_test))]), len(x_test))
# Out:
# 444 872

# %%
# model evaluation

print("Doc2Vec, LSTM, no balancing techniques")
print("F-measure or f1-score: ", f1_score(y_test, [math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))]))
print("Log loss: ", log_loss(y_test, predictions_lstm))
print("Log loss: ", log_loss(y_test, [math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))]))

fpr, tpr, thresholds = roc_curve(y_test, predictions_lstm)

print("AUC: ", auc(fpr, tpr))

fpr, tpr, thresholds = roc_curve(y_test,[math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))])

print("AUC: ", auc(fpr, tpr))

eval(y_test, [math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))])
# Out:
# Doc2Vec, LSTM, no balancing techniques
# F-measure or f1-score:  0.6747720364741641
# Log loss:  nan
# Log loss:  16.95291115220401
# AUC:  0.7301138755578009
# AUC:  0.5
# Classification Report:
#               precision    recall  f1-score   support
#
#            1     0.5092    1.0000    0.6748       444
#            0     0.0000    0.0000    0.0000       428
#
#     accuracy                         0.5092       872
#    macro avg     0.2546    0.5000    0.3374       872
# weighted avg     0.2593    0.5092    0.3436       872

# %% [markdown]
# ## LSTM architecture 6

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
from matplotlib import pyplot
from keras.layers import Bidirectional

# %%
lstm = Sequential()
lstm.add(Bidirectional(LSTM(100, dropout=0.2, recurrent_dropout=0.2)))
lstm.add(Dense(10, activation='softmax'))
lstm.add(Dense(1, activation='sigmoid'))

callback = EarlyStopping(monitor='val_loss', patience=7)

lstm.compile(loss='binary_crossentropy', optimizer='adam')
lstm.fit(np.array(x_train_preprocessed).reshape([len(x_train_preprocessed),1,vector_size]), y_train, validation_data=(np.array(x_valid_preprocessed).reshape([len(x_valid_preprocessed),1,vector_size]), y_valid), epochs=50, batch_size=128, verbose=1, shuffle=True, callbacks=[callback])
# Out:
# Epoch 1/50
#  - ETA: 3s - loss: 0.6843
# Epoch 2/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.6487 - val_loss: 0.6440
# Epoch 3/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.6453 - val_loss: 0.6436
# Epoch 4/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.6428 - val_loss: 0.6414
# Epoch 5/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.6398 - val_loss: 0.6384
# Epoch 6/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.6377 - val_loss: 0.6369
# Epoch 7/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.6337 - val_loss: 0.6343
# Epoch 8/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.6303 - val_loss: 0.6354
# Epoch 9/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.6281 - val_loss: 0.6308
# Epoch 10/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.6258 - val_loss: 0.6277
# Epoch 11/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.6219 - val_loss: 0.6256
# Epoch 12/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.6192 - val_loss: 0.6261
# Epoch 13/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.6157 - val_loss: 0.6227
# Epoch 14/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.6120 - val_loss: 0.6204
# Epoch 15/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.6097 - val_loss: 0.6180
# Epoch 16/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.6056 - val_loss: 0.6161
# Epoch 17/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.6037 - val_loss: 0.6171
# Epoch 18/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.6004 - val_loss: 0.6184
# Epoch 19/50
# 493/493 [==============================] - 5s 11ms/step - loss: 0.5987 - val_loss: 0.6100
# Epoch 20/50
# 493/493 [==============================] - 5s 11ms/step - loss: 0.5944 - val_loss: 0.6135
# Epoch 21/50
# 493/493 [==============================] - 6s 12ms/step - loss: 0.5916 - val_loss: 0.6119
# Epoch 22/50
# 493/493 [==============================] - 5s 10ms/step - loss: 0.5904 - val_loss: 0.6061
# Epoch 23/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5887 - val_loss: 0.6057
# Epoch 24/50
#  - ETA: 3s - loss: 0.5824
# Epoch 25/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5838 - val_loss: 0.6041
# Epoch 26/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5821 - val_loss: 0.6024
# Epoch 27/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5787 - val_loss: 0.6003
# Epoch 28/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5769 - val_loss: 0.6021
# Epoch 29/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5750 - val_loss: 0.5979
# Epoch 30/50
# 493/493 [==============================] - 5s 9ms/step - loss: 0.5727 - val_loss: 0.6045
# Epoch 31/50
#  - ETA: 0s - loss: 0.5714
# Epoch 32/50
# 493/493 [==============================] - 5s 10ms/step - loss: 0.5691 - val_loss: 0.5946
# Epoch 33/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5677 - val_loss: 0.5983
# Epoch 34/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5663 - val_loss: 0.5959
# Epoch 35/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5640 - val_loss: 0.5959
# Epoch 36/50
# 493/493 [==============================] - 4s 9ms/step - loss: 0.5600 - val_loss: 0.5973
# Epoch 37/50
#  - 4s 9ms/step - loss: 0.5610 - val_loss: 0.5967
# Epoch 38/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5579 - val_loss: 0.5950
# Epoch 39/50
# 493/493 [==============================] - 4s 8ms/step - loss: 0.5566 - val_loss: 0.6036

# %%
import math

predictions_lstm = lstm.predict(np.array(x_test_preprocessed).reshape([len(x_test_preprocessed),1,vector_size]))

print(sum([math.ceil(predictions_lstm[i]) == y_test[i] for i in range(len(x_test))]), len(x_test))
# Out:
# 444 872

# %%
# model evaluation

print("Doc2Vec, LSTM, no balancing techniques")
print("F-measure or f1-score: ", f1_score(y_test, [math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))]))
print("Log loss: ", log_loss(y_test, predictions_lstm))
print("Log loss: ", log_loss(y_test, [math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))]))

fpr, tpr, thresholds = roc_curve(y_test, predictions_lstm)

print("AUC: ", auc(fpr, tpr))

fpr, tpr, thresholds = roc_curve(y_test,[math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))])

print("AUC: ", auc(fpr, tpr))

eval(y_test, [math.ceil(predictions_lstm[i]) for i in range(len(predictions_lstm))])
# Out:
# Doc2Vec, LSTM, no balancing techniques
# F-measure or f1-score:  0.6747720364741641
# Log loss:  0.7228584908965736
# Log loss:  16.95291115220401
# AUC:  0.7359549970531278
# AUC:  0.5
# Classification Report:
#               precision    recall  f1-score   support
#
#            1     0.5092    1.0000    0.6748       444
#            0     0.0000    0.0000    0.0000       428
#
#     accuracy                         0.5092       872
#    macro avg     0.2546    0.5000    0.3374       872
# weighted avg     0.2593    0.5092    0.3436       872
